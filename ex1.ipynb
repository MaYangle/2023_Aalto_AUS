# %% [markdown]
# <div class="alert alert-block alert-info">
#    <h2 align="center"> <center><b> Reinforcement Learning Assignment 1 - The Reinforcement Learning Framework</b></center></h2>
#
# <br>
# <center><font size="3">This notebook is a part of teaching material for ELEC-E8125</font></center>
# <center><font size="3">Sep 4, 2023 - Nov 30, 2023</font></center>
# <center><font size="3">Aalto University</font></center>
# </div>
#
#
# <a id='TOC'></a>
#
# <div class="alert alert-block alert-success">
#
# # Table of contents
# * <a href='#1.'> 1. Introduction </a>
# * <a href='#1.1'> 1.1 Learning Objectives </a>
# * <a href='#1.2'> 1.2 Code Structure & Files </a>
# * <a href='#2.'> 2. Cartpole</a>
# * <a href='#3.'> 3. Reacher</a>
# * <a href='#4.'> 4. Submitting </a>
# * <a href='#4.1'> 4.1 Feedback </a>
# * <a href='#5.'> References</a>
#
# <a href='#T1'><b>Student Task 1.</b> Training a Model for Simple Cartpole Environment (10 points)</a>\
# <a href='#Q1'><b>Student Question 1.1</b> Learning (10 points)</a>\
# <a href='#T2'><b>Student Task 2.</b> Investigating Training Performance (10 points) </a>\
# <a href='#Q2'><b>Student Question 2.1</b> Analysis of Training Performance (15 points) </a>\
# <a href='#Q3'><b>Student Question 2.2</b> Stochasticity (10 points) </a>\
# <a href='#T3'><b>Student Task 3.</b> Reward Functions (20 points) </a>\
# <a href='#T4'><b>Student Task 4.</b> Visualizing Behavior (10 points) </a>\
# <a href='#Q4'><b>Student Question 4.1</b> Achieved Peformance (5 points)\
# <a href='#Q5'><b>Student Question 4.2</b> Analysis of Behaviour (10 points)</a>
#
# **Total Points:** 100

# %% [markdown]
# # 1. Introduction <a id='1.'></a>
# In this exercise we will take a first look at a reinforcement learning environment, its components and modify the reward function of a simple agent.
#
# In this notebook two environments are used: Cartpole and Reacher. The cartpole environment is taken from [OpenAI's Gym library](https://www.gymlibrary.dev/). The reacher environment is custom made (and defined in ```reacher.py```) but utilizes the Gym API.
#
# ## 1.1 Learning Objectives: <a id='1.1'></a>
# - To become familiar with assignment structure and the agent-environment relationshp
# - To understand the effects of stochasticity
# - To understand and explore the effects of task definition
#
# ## 1.2 Code Structure & Files <a id='1.2'></a>
#
# The ```train.py``` file instantiates the environment and the RL agent that acts in it. The ```agent.py``` file contains the implementation of a simple reinforcement learning agent; for the sake of this exercise, you can assume it to be a black box (you don’t need to understand how it works, although you are encouraged to study it in more detail). You don’t have to edit any other file other than ```ex1.ipynb``` to complete this exercise.
# ```
# ├───cfg                  # Config files for environments e.g. define the maximum number of steps in an episode.
# ├───imgs                 # Images used in notebook
# ├───results
# │   ├───logging          # Contains logged data
# │   ├───model            # Contains the policies learned
# │   └───video            # Contains videos for each environment
# │       └───CartPole-v0
# │       │  └───test      # Videos saved during testing
# │       │  └───train     # Videos saved during training
# │       └───SpinningReacher-v0
# │           └───test
# │           └───train
# ├───wandb                # Data saved for wandb
# │   ex1.ipynb            # Main assignment file containing tasks <---------
# │   feedback.ipynb       # Please give feedback in here
# │   README.ipynb         # This file
# │   agent.py             # Contains functions that govern the policy
# │   reacher.py           # Defines the reacher environment
# │   train.py             # Contains training and testing functions
# │   utils.py             # Contains useful functions
# ```

# %% [markdown]
# Please consult ```README.md``` for more details the assignments.
#
# The assignments use wandb to visualize data. You need to set Wandb up and login using the command below.

# %%
! wandb login b6c6eb76fa155bd3ab2312aa76f74ca57a68331b  # Insert API key here. You can get your API key from https://wandb.ai/authorize
# Out:
# /bin/bash: line 1: wandb: command not found

# %%
from pathlib import Path # to find directory
work_dir = Path().cwd()/'results'
import os
os.environ['WANDB_NOTEBOOK_NAME'] = str(Path().cwd()/'ex1.ipynb') # Detects notebook for wandb

import train as t # for training
import utils as u # helper functions

import numpy as np # The numpy library can be used for math functions
import torch # Used to manage policy and learning
from IPython.display import Video, display, HTML # to display videos

# %% [markdown]
# # 2. Cartpole <a id='2.'></a>
#
# The Cartpole environment consists of a cart and a pole mounted on top of it, as shown in Figure 1. The cart can move either to the left or to the right. The goal is to balance the pole in a vertical position in order to prevent it from falling down. The cart should also stay within limited distance from the center (trying to move outside screen boundaries is considered a failure).
#
# <figure>
# <img src="imgs/cartpole.png" width="400px">
# <figcaption style="text-align: center"> Figure 1: The Cartpole environment  </figcaption>
# </figure>
#
# The state and the observation are four element vectors:
#
# $$
# o=s=\left(\begin{array}{c}
# x \\
# \dot{x} \\
# \theta \\
# \dot{\theta}
# \end{array}\right) \text {, }
# $$
#
# where $x$ is the position of the cart, $\dot{x}$ is its velocity, $\theta$ is the angle of the pole w.r.t. the vertical axis, and $\dot{\theta}$ is the angular velocity of the pole.
#
# In the standard formulation, a reward of 1 is given for every timestep the pole remains balanced. Upon failing (the pole falls) or completing the task, an episode is finished.
#
# The training script will record videos of the agent’s learning progress during training, and the recorded videos are saved to ```results/video/CartPole-v0/train```. By default, the training information is saved to ```results/logging/CartPole-v0_logging.pkl``` as well as on cloud via wandb. When the training is finished, the models are saved to ```results/model/Cartpole-v0_params.pt```. The models can be tested by setting ```testing=true``` in ```cfg_args```, and if the models are saved to a different path, you can use ```model_path=<YOUR MODEL PATH>``` to indicate it. Videos of the agent’s behaviour during testing are saved to ```results/video/CartPole-v0/test```.

# %% [markdown]
# <a id='T1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 1.</b> Training a Model for Simple Cartpole Environment (10 points) </h3>
#
# This task requires you to train a model for the cartpole environment with 100 timesteps per episode and then report the training plot using 'Weights \& Biases'. Then test the model for 1000 timesteps and report average reward. To do this, you can simply run the code in the cells below.
#
# To see a full list of options that can be passed through ```cfg_args``` consult the configuation file found in ```cfg/```.
#
# - **1st:** setup 'Weights \& Biases', check the README for help.
# - **2nd:** Run training over 100 steps per episode by using ```t.train``` function. See the cell below.
# - **3rd:** Export the training plot ```episodesep_reward``` from wandb (see ```README.md```) and attach below.
#
# - **4th:** Run testing over 1000 steps by using ```t.test``` function. See the cell below. See the cell below. Notice ```max_episode_steps``` parameter.
# - **5th:** Report the average reward after testing the model.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
t.train(cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
        cfg_args=dict(seed=1, max_episode_steps=100)) # < 5 mins
# Out:
# Numpy/Torch/Random Seed:  1
# wandb version 0.15.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/notebooks/rl2023/ex1/wandb/run-20230916_090655-gmrnx58z</code>
# Syncing run <strong><a href='https://wandb.ai/mayangle/rl_aalto/runs/gmrnx58z' target="_blank">ex1-CartPole-v1-1-1694844414</a></strong> to <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">https://wandb.ai/mayangle/rl_aalto</a>
#  View run at <a href='https://wandb.ai/mayangle/rl_aalto/runs/gmrnx58z' target="_blank">https://wandb.ai/mayangle/rl_aalto/runs/gmrnx58z</a>
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/CartPole-v1/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Configuration Settings: {'exp_name': 'ex1', 'seed': 1, 'env_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Episode 0 finished. Total reward: 28.0 (28 timesteps)
# Episode 1 finished. Total reward: 34.0 (34 timesteps)
# Episode 2 finished. Total reward: 17.0 (17 timesteps)
# Episode 3 finished. Total reward: 11.0 (11 timesteps)
# Episode 4 finished. Total reward: 34.0 (34 timesteps)
# Episode 5 finished. Total reward: 18.0 (18 timesteps)
# Episode 6 finished. Total reward: 76.0 (76 timesteps)
# Episode 7 finished. Total reward: 12.0 (12 timesteps)
# Episode 8 finished. Total reward: 10.0 (10 timesteps)
# Episode 9 finished. Total reward: 41.0 (41 timesteps)
# Episode 10 finished. Total reward: 33.0 (33 timesteps)
# Episode 11 finished. Total reward: 20.0 (20 timesteps)
# Episode 12 finished. Total reward: 29.0 (29 timesteps)
# Episode 13 finished. Total reward: 11.0 (11 timesteps)
# Episode 14 finished. Total reward: 15.0 (15 timesteps)
# Episode 15 finished. Total reward: 14.0 (14 timesteps)
# Episode 16 finished. Total reward: 11.0 (11 timesteps)
# Episode 17 finished. Total reward: 14.0 (14 timesteps)
# Episode 18 finished. Total reward: 28.0 (28 timesteps)
# Episode 19 finished. Total reward: 15.0 (15 timesteps)
# Episode 20 finished. Total reward: 10.0 (10 timesteps)
# Episode 21 finished. Total reward: 17.0 (17 timesteps)
# Episode 22 finished. Total reward: 17.0 (17 timesteps)
# Episode 23 finished. Total reward: 44.0 (44 timesteps)
# Episode 24 finished. Total reward: 17.0 (17 timesteps)
# Episode 25 finished. Total reward: 17.0 (17 timesteps)
# Episode 26 finished. Total reward: 15.0 (15 timesteps)
# Episode 27 finished. Total reward: 23.0 (23 timesteps)
# Episode 28 finished. Total reward: 15.0 (15 timesteps)
# Episode 29 finished. Total reward: 17.0 (17 timesteps)
# Episode 30 finished. Total reward: 10.0 (10 timesteps)
# Episode 31 finished. Total reward: 31.0 (31 timesteps)
# Episode 32 finished. Total reward: 12.0 (12 timesteps)
# Episode 33 finished. Total reward: 14.0 (14 timesteps)
# Episode 34 finished. Total reward: 10.0 (10 timesteps)
# Episode 35 finished. Total reward: 11.0 (11 timesteps)
# Episode 36 finished. Total reward: 35.0 (35 timesteps)
# Episode 37 finished. Total reward: 19.0 (19 timesteps)
# Episode 38 finished. Total reward: 12.0 (12 timesteps)
# Episode 39 finished. Total reward: 9.0 (9 timesteps)
# Episode 40 finished. Total reward: 12.0 (12 timesteps)
# Episode 41 finished. Total reward: 14.0 (14 timesteps)
# Episode 42 finished. Total reward: 14.0 (14 timesteps)
# Episode 43 finished. Total reward: 20.0 (20 timesteps)
# Episode 44 finished. Total reward: 46.0 (46 timesteps)
# Episode 45 finished. Total reward: 25.0 (25 timesteps)
# Episode 46 finished. Total reward: 14.0 (14 timesteps)
# Episode 47 finished. Total reward: 13.0 (13 timesteps)
# Episode 48 finished. Total reward: 18.0 (18 timesteps)
# Episode 49 finished. Total reward: 17.0 (17 timesteps)
# Episode 50 finished. Total reward: 21.0 (21 timesteps)
# Episode 51 finished. Total reward: 23.0 (23 timesteps)
# Episode 52 finished. Total reward: 15.0 (15 timesteps)
# Episode 53 finished. Total reward: 62.0 (62 timesteps)
# Episode 54 finished. Total reward: 18.0 (18 timesteps)
# Episode 55 finished. Total reward: 21.0 (21 timesteps)
# Episode 56 finished. Total reward: 25.0 (25 timesteps)
# Episode 57 finished. Total reward: 14.0 (14 timesteps)
# Episode 58 finished. Total reward: 14.0 (14 timesteps)
# Episode 59 finished. Total reward: 25.0 (25 timesteps)
# Episode 60 finished. Total reward: 14.0 (14 timesteps)
# Episode 61 finished. Total reward: 19.0 (19 timesteps)
# Episode 62 finished. Total reward: 13.0 (13 timesteps)
# Episode 63 finished. Total reward: 11.0 (11 timesteps)
# Episode 64 finished. Total reward: 24.0 (24 timesteps)
# Episode 65 finished. Total reward: 21.0 (21 timesteps)
# Episode 66 finished. Total reward: 31.0 (31 timesteps)
# Episode 67 finished. Total reward: 83.0 (83 timesteps)
# Episode 68 finished. Total reward: 12.0 (12 timesteps)
# Episode 69 finished. Total reward: 17.0 (17 timesteps)
# Episode 70 finished. Total reward: 49.0 (49 timesteps)
# Episode 71 finished. Total reward: 18.0 (18 timesteps)
# Episode 72 finished. Total reward: 22.0 (22 timesteps)
# Episode 73 finished. Total reward: 23.0 (23 timesteps)
# Episode 74 finished. Total reward: 30.0 (30 timesteps)
# Episode 75 finished. Total reward: 15.0 (15 timesteps)
# Episode 76 finished. Total reward: 22.0 (22 timesteps)
# Episode 77 finished. Total reward: 55.0 (55 timesteps)
# Episode 78 finished. Total reward: 15.0 (15 timesteps)
# Episode 79 finished. Total reward: 12.0 (12 timesteps)
# Episode 80 finished. Total reward: 37.0 (37 timesteps)
# Episode 81 finished. Total reward: 9.0 (9 timesteps)
# Episode 82 finished. Total reward: 13.0 (13 timesteps)
# Episode 83 finished. Total reward: 16.0 (16 timesteps)
# Episode 84 finished. Total reward: 10.0 (10 timesteps)
# Episode 85 finished. Total reward: 27.0 (27 timesteps)
# Episode 86 finished. Total reward: 14.0 (14 timesteps)
# Episode 87 finished. Total reward: 20.0 (20 timesteps)
# Episode 88 finished. Total reward: 29.0 (29 timesteps)
# Episode 89 finished. Total reward: 9.0 (9 timesteps)
# Episode 90 finished. Total reward: 13.0 (13 timesteps)
# Episode 91 finished. Total reward: 13.0 (13 timesteps)
# Episode 92 finished. Total reward: 19.0 (19 timesteps)
# Updating the policy...
# Updating finished!
# Episode 93 finished. Total reward: 50.0 (50 timesteps)
# Episode 94 finished. Total reward: 24.0 (24 timesteps)
# Episode 95 finished. Total reward: 38.0 (38 timesteps)
# Episode 96 finished. Total reward: 19.0 (19 timesteps)
# Episode 97 finished. Total reward: 13.0 (13 timesteps)
# Episode 98 finished. Total reward: 20.0 (20 timesteps)
# Episode 99 finished. Total reward: 14.0 (14 timesteps)
# Episode 100 finished. Total reward: 50.0 (50 timesteps)
# Episode 101 finished. Total reward: 20.0 (20 timesteps)
# Episode 102 finished. Total reward: 49.0 (49 timesteps)
# Episode 103 finished. Total reward: 32.0 (32 timesteps)
# Episode 104 finished. Total reward: 21.0 (21 timesteps)
# Episode 105 finished. Total reward: 10.0 (10 timesteps)
# Episode 106 finished. Total reward: 26.0 (26 timesteps)
# Episode 107 finished. Total reward: 16.0 (16 timesteps)
# Episode 108 finished. Total reward: 12.0 (12 timesteps)
# Episode 109 finished. Total reward: 23.0 (23 timesteps)
# Episode 110 finished. Total reward: 23.0 (23 timesteps)
# Episode 111 finished. Total reward: 18.0 (18 timesteps)
# Episode 112 finished. Total reward: 50.0 (50 timesteps)
# Episode 113 finished. Total reward: 13.0 (13 timesteps)
# Episode 114 finished. Total reward: 56.0 (56 timesteps)
# Episode 115 finished. Total reward: 13.0 (13 timesteps)
# Episode 116 finished. Total reward: 96.0 (96 timesteps)
# Episode 117 finished. Total reward: 28.0 (28 timesteps)
# Episode 118 finished. Total reward: 60.0 (60 timesteps)
# Episode 119 finished. Total reward: 46.0 (46 timesteps)
# Episode 120 finished. Total reward: 23.0 (23 timesteps)
# Episode 121 finished. Total reward: 26.0 (26 timesteps)
# Episode 122 finished. Total reward: 26.0 (26 timesteps)
# Episode 123 finished. Total reward: 57.0 (57 timesteps)
# Episode 124 finished. Total reward: 20.0 (20 timesteps)
# Episode 125 finished. Total reward: 15.0 (15 timesteps)
# Episode 126 finished. Total reward: 18.0 (18 timesteps)
# Episode 127 finished. Total reward: 25.0 (25 timesteps)
# Episode 128 finished. Total reward: 30.0 (30 timesteps)
# Episode 129 finished. Total reward: 46.0 (46 timesteps)
# Episode 130 finished. Total reward: 20.0 (20 timesteps)
# Episode 131 finished. Total reward: 64.0 (64 timesteps)
# Episode 132 finished. Total reward: 42.0 (42 timesteps)
# Episode 133 finished. Total reward: 19.0 (19 timesteps)
# Episode 134 finished. Total reward: 28.0 (28 timesteps)
# Episode 135 finished. Total reward: 28.0 (28 timesteps)
# Episode 136 finished. Total reward: 40.0 (40 timesteps)
# Episode 137 finished. Total reward: 23.0 (23 timesteps)
# Episode 138 finished. Total reward: 15.0 (15 timesteps)
# Episode 139 finished. Total reward: 22.0 (22 timesteps)
# Episode 140 finished. Total reward: 42.0 (42 timesteps)
# Episode 141 finished. Total reward: 40.0 (40 timesteps)
# Episode 142 finished. Total reward: 34.0 (34 timesteps)
# Episode 143 finished. Total reward: 64.0 (64 timesteps)
# Episode 144 finished. Total reward: 14.0 (14 timesteps)
# Episode 145 finished. Total reward: 32.0 (32 timesteps)
# Episode 146 finished. Total reward: 21.0 (21 timesteps)
# Episode 147 finished. Total reward: 17.0 (17 timesteps)
# Episode 148 finished. Total reward: 24.0 (24 timesteps)
# Episode 149 finished. Total reward: 9.0 (9 timesteps)
# Episode 150 finished. Total reward: 100.0 (100 timesteps)
# Episode 151 finished. Total reward: 54.0 (54 timesteps)
# Episode 152 finished. Total reward: 14.0 (14 timesteps)
# Episode 153 finished. Total reward: 26.0 (26 timesteps)
# Episode 154 finished. Total reward: 72.0 (72 timesteps)
# Episode 155 finished. Total reward: 10.0 (10 timesteps)
# Updating the policy...
# Updating finished!
# Episode 156 finished. Total reward: 57.0 (57 timesteps)
# Episode 157 finished. Total reward: 16.0 (16 timesteps)
# Episode 158 finished. Total reward: 30.0 (30 timesteps)
# Episode 159 finished. Total reward: 35.0 (35 timesteps)
# Episode 160 finished. Total reward: 23.0 (23 timesteps)
# Episode 161 finished. Total reward: 41.0 (41 timesteps)
# Episode 162 finished. Total reward: 64.0 (64 timesteps)
# Episode 163 finished. Total reward: 18.0 (18 timesteps)
# Episode 164 finished. Total reward: 14.0 (14 timesteps)
# Episode 165 finished. Total reward: 22.0 (22 timesteps)
# Episode 166 finished. Total reward: 32.0 (32 timesteps)
# Episode 167 finished. Total reward: 100.0 (100 timesteps)
# Episode 168 finished. Total reward: 47.0 (47 timesteps)
# Episode 169 finished. Total reward: 12.0 (12 timesteps)
# Episode 170 finished. Total reward: 31.0 (31 timesteps)
# Episode 171 finished. Total reward: 25.0 (25 timesteps)
# Episode 172 finished. Total reward: 17.0 (17 timesteps)
# Episode 173 finished. Total reward: 100.0 (100 timesteps)
# Episode 174 finished. Total reward: 24.0 (24 timesteps)
# Episode 175 finished. Total reward: 13.0 (13 timesteps)
# Episode 176 finished. Total reward: 48.0 (48 timesteps)
# Episode 177 finished. Total reward: 21.0 (21 timesteps)
# Episode 178 finished. Total reward: 42.0 (42 timesteps)
# Episode 179 finished. Total reward: 39.0 (39 timesteps)
# Episode 180 finished. Total reward: 15.0 (15 timesteps)
# Episode 181 finished. Total reward: 25.0 (25 timesteps)
# Episode 182 finished. Total reward: 52.0 (52 timesteps)
# Episode 183 finished. Total reward: 27.0 (27 timesteps)
# Episode 184 finished. Total reward: 100.0 (100 timesteps)
# Episode 185 finished. Total reward: 36.0 (36 timesteps)
# Episode 186 finished. Total reward: 83.0 (83 timesteps)
# Episode 187 finished. Total reward: 74.0 (74 timesteps)
# Episode 188 finished. Total reward: 13.0 (13 timesteps)
# Episode 189 finished. Total reward: 33.0 (33 timesteps)
# Episode 190 finished. Total reward: 100.0 (100 timesteps)
# Episode 191 finished. Total reward: 10.0 (10 timesteps)
# Episode 192 finished. Total reward: 31.0 (31 timesteps)
# Episode 193 finished. Total reward: 100.0 (100 timesteps)
# Episode 194 finished. Total reward: 43.0 (43 timesteps)
# Episode 195 finished. Total reward: 74.0 (74 timesteps)
# Episode 196 finished. Total reward: 19.0 (19 timesteps)
# Episode 197 finished. Total reward: 13.0 (13 timesteps)
# Episode 198 finished. Total reward: 16.0 (16 timesteps)
# Episode 199 finished. Total reward: 100.0 (100 timesteps)
# Episode 200 finished. Total reward: 46.0 (46 timesteps)
# Episode 201 finished. Total reward: 33.0 (33 timesteps)
# Episode 202 finished. Total reward: 51.0 (51 timesteps)
# Episode 203 finished. Total reward: 16.0 (16 timesteps)
# Updating the policy...
# Updating finished!
# Episode 204 finished. Total reward: 90.0 (90 timesteps)
# Episode 205 finished. Total reward: 100.0 (100 timesteps)
# Episode 206 finished. Total reward: 18.0 (18 timesteps)
# Episode 207 finished. Total reward: 48.0 (48 timesteps)
# Episode 208 finished. Total reward: 31.0 (31 timesteps)
# Episode 209 finished. Total reward: 63.0 (63 timesteps)
# Episode 210 finished. Total reward: 19.0 (19 timesteps)
# Episode 211 finished. Total reward: 32.0 (32 timesteps)
# Episode 212 finished. Total reward: 100.0 (100 timesteps)
# Episode 213 finished. Total reward: 100.0 (100 timesteps)
# Episode 214 finished. Total reward: 61.0 (61 timesteps)
# Episode 215 finished. Total reward: 100.0 (100 timesteps)
# Episode 216 finished. Total reward: 17.0 (17 timesteps)
# Episode 217 finished. Total reward: 84.0 (84 timesteps)
# Episode 218 finished. Total reward: 100.0 (100 timesteps)
# Episode 219 finished. Total reward: 100.0 (100 timesteps)
# Episode 220 finished. Total reward: 98.0 (98 timesteps)
# Episode 221 finished. Total reward: 100.0 (100 timesteps)
# Episode 222 finished. Total reward: 100.0 (100 timesteps)
# Episode 223 finished. Total reward: 22.0 (22 timesteps)
# Episode 224 finished. Total reward: 99.0 (99 timesteps)
# Episode 225 finished. Total reward: 100.0 (100 timesteps)
# Episode 226 finished. Total reward: 46.0 (46 timesteps)
# Episode 227 finished. Total reward: 74.0 (74 timesteps)
# Episode 228 finished. Total reward: 100.0 (100 timesteps)
# Episode 229 finished. Total reward: 59.0 (59 timesteps)
# Episode 230 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 231 finished. Total reward: 100.0 (100 timesteps)
# Episode 232 finished. Total reward: 100.0 (100 timesteps)
# Episode 233 finished. Total reward: 100.0 (100 timesteps)
# Episode 234 finished. Total reward: 100.0 (100 timesteps)
# Episode 235 finished. Total reward: 100.0 (100 timesteps)
# Episode 236 finished. Total reward: 100.0 (100 timesteps)
# Episode 237 finished. Total reward: 36.0 (36 timesteps)
# Episode 238 finished. Total reward: 100.0 (100 timesteps)
# Episode 239 finished. Total reward: 100.0 (100 timesteps)
# Episode 240 finished. Total reward: 100.0 (100 timesteps)
# Episode 241 finished. Total reward: 100.0 (100 timesteps)
# Episode 242 finished. Total reward: 100.0 (100 timesteps)
# Episode 243 finished. Total reward: 100.0 (100 timesteps)
# Episode 244 finished. Total reward: 52.0 (52 timesteps)
# Episode 245 finished. Total reward: 100.0 (100 timesteps)
# Episode 246 finished. Total reward: 14.0 (14 timesteps)
# Episode 247 finished. Total reward: 55.0 (55 timesteps)
# Episode 248 finished. Total reward: 100.0 (100 timesteps)
# Episode 249 finished. Total reward: 100.0 (100 timesteps)
# Episode 250 finished. Total reward: 100.0 (100 timesteps)
# Episode 251 finished. Total reward: 52.0 (52 timesteps)
# Episode 252 finished. Total reward: 100.0 (100 timesteps)
# Episode 253 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 254 finished. Total reward: 100.0 (100 timesteps)
# Episode 255 finished. Total reward: 100.0 (100 timesteps)
# Episode 256 finished. Total reward: 100.0 (100 timesteps)
# Episode 257 finished. Total reward: 100.0 (100 timesteps)
# Episode 258 finished. Total reward: 54.0 (54 timesteps)
# Episode 259 finished. Total reward: 100.0 (100 timesteps)
# Episode 260 finished. Total reward: 100.0 (100 timesteps)
# Episode 261 finished. Total reward: 100.0 (100 timesteps)
# Episode 262 finished. Total reward: 100.0 (100 timesteps)
# Episode 263 finished. Total reward: 100.0 (100 timesteps)
# Episode 264 finished. Total reward: 100.0 (100 timesteps)
# Episode 265 finished. Total reward: 100.0 (100 timesteps)
# Episode 266 finished. Total reward: 100.0 (100 timesteps)
# Episode 267 finished. Total reward: 100.0 (100 timesteps)
# Episode 268 finished. Total reward: 100.0 (100 timesteps)
# Episode 269 finished. Total reward: 100.0 (100 timesteps)
# Episode 270 finished. Total reward: 20.0 (20 timesteps)
# Episode 271 finished. Total reward: 100.0 (100 timesteps)
# Episode 272 finished. Total reward: 19.0 (19 timesteps)
# Episode 273 finished. Total reward: 100.0 (100 timesteps)
# Episode 274 finished. Total reward: 100.0 (100 timesteps)
# Episode 275 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 276 finished. Total reward: 95.0 (95 timesteps)
# Episode 277 finished. Total reward: 100.0 (100 timesteps)
# Episode 278 finished. Total reward: 100.0 (100 timesteps)
# Episode 279 finished. Total reward: 100.0 (100 timesteps)
# Episode 280 finished. Total reward: 100.0 (100 timesteps)
# Episode 281 finished. Total reward: 100.0 (100 timesteps)
# Episode 282 finished. Total reward: 91.0 (91 timesteps)
# Episode 283 finished. Total reward: 100.0 (100 timesteps)
# Episode 284 finished. Total reward: 79.0 (79 timesteps)
# Episode 285 finished. Total reward: 100.0 (100 timesteps)
# Episode 286 finished. Total reward: 100.0 (100 timesteps)
# Episode 287 finished. Total reward: 100.0 (100 timesteps)
# Episode 288 finished. Total reward: 100.0 (100 timesteps)
# Episode 289 finished. Total reward: 100.0 (100 timesteps)
# Episode 290 finished. Total reward: 100.0 (100 timesteps)
# Episode 291 finished. Total reward: 100.0 (100 timesteps)
# Episode 292 finished. Total reward: 100.0 (100 timesteps)
# Episode 293 finished. Total reward: 90.0 (90 timesteps)
# Episode 294 finished. Total reward: 100.0 (100 timesteps)
# Episode 295 finished. Total reward: 100.0 (100 timesteps)
# Episode 296 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 297 finished. Total reward: 100.0 (100 timesteps)
# Episode 298 finished. Total reward: 100.0 (100 timesteps)
# Episode 299 finished. Total reward: 100.0 (100 timesteps)
# Episode 300 finished. Total reward: 100.0 (100 timesteps)
# Episode 301 finished. Total reward: 68.0 (68 timesteps)
# Episode 302 finished. Total reward: 100.0 (100 timesteps)
# Episode 303 finished. Total reward: 100.0 (100 timesteps)
# Episode 304 finished. Total reward: 100.0 (100 timesteps)
# Episode 305 finished. Total reward: 100.0 (100 timesteps)
# Episode 306 finished. Total reward: 100.0 (100 timesteps)
# Episode 307 finished. Total reward: 100.0 (100 timesteps)
# Episode 308 finished. Total reward: 100.0 (100 timesteps)
# Episode 309 finished. Total reward: 100.0 (100 timesteps)
# Episode 310 finished. Total reward: 100.0 (100 timesteps)
# Episode 311 finished. Total reward: 100.0 (100 timesteps)
# Episode 312 finished. Total reward: 100.0 (100 timesteps)
# Episode 313 finished. Total reward: 100.0 (100 timesteps)
# Episode 314 finished. Total reward: 100.0 (100 timesteps)
# Episode 315 finished. Total reward: 100.0 (100 timesteps)
# Episode 316 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 317 finished. Total reward: 100.0 (100 timesteps)
# Episode 318 finished. Total reward: 100.0 (100 timesteps)
# Episode 319 finished. Total reward: 100.0 (100 timesteps)
# Episode 320 finished. Total reward: 100.0 (100 timesteps)
# Episode 321 finished. Total reward: 100.0 (100 timesteps)
# Episode 322 finished. Total reward: 100.0 (100 timesteps)
# Episode 323 finished. Total reward: 100.0 (100 timesteps)
# Episode 324 finished. Total reward: 100.0 (100 timesteps)
# Episode 325 finished. Total reward: 100.0 (100 timesteps)
# Episode 326 finished. Total reward: 100.0 (100 timesteps)
# Episode 327 finished. Total reward: 100.0 (100 timesteps)
# Episode 328 finished. Total reward: 100.0 (100 timesteps)
# Episode 329 finished. Total reward: 100.0 (100 timesteps)
# Episode 330 finished. Total reward: 100.0 (100 timesteps)
# Episode 331 finished. Total reward: 100.0 (100 timesteps)
# Episode 332 finished. Total reward: 100.0 (100 timesteps)
# Episode 333 finished. Total reward: 100.0 (100 timesteps)
# Episode 334 finished. Total reward: 100.0 (100 timesteps)
# Episode 335 finished. Total reward: 100.0 (100 timesteps)
# Episode 336 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 337 finished. Total reward: 100.0 (100 timesteps)
# Episode 338 finished. Total reward: 100.0 (100 timesteps)
# Episode 339 finished. Total reward: 100.0 (100 timesteps)
# Episode 340 finished. Total reward: 100.0 (100 timesteps)
# Episode 341 finished. Total reward: 100.0 (100 timesteps)
# Episode 342 finished. Total reward: 100.0 (100 timesteps)
# Episode 343 finished. Total reward: 100.0 (100 timesteps)
# Episode 344 finished. Total reward: 84.0 (84 timesteps)
# Episode 345 finished. Total reward: 100.0 (100 timesteps)
# Episode 346 finished. Total reward: 100.0 (100 timesteps)
# Episode 347 finished. Total reward: 100.0 (100 timesteps)
# Episode 348 finished. Total reward: 17.0 (17 timesteps)
# Episode 349 finished. Total reward: 100.0 (100 timesteps)
# Episode 350 finished. Total reward: 100.0 (100 timesteps)
# Episode 351 finished. Total reward: 100.0 (100 timesteps)
# Episode 352 finished. Total reward: 100.0 (100 timesteps)
# Episode 353 finished. Total reward: 100.0 (100 timesteps)
# Episode 354 finished. Total reward: 100.0 (100 timesteps)
# Episode 355 finished. Total reward: 100.0 (100 timesteps)
# Episode 356 finished. Total reward: 100.0 (100 timesteps)
# Episode 357 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 358 finished. Total reward: 100.0 (100 timesteps)
# Episode 359 finished. Total reward: 100.0 (100 timesteps)
# Episode 360 finished. Total reward: 100.0 (100 timesteps)
# Episode 361 finished. Total reward: 100.0 (100 timesteps)
# Episode 362 finished. Total reward: 100.0 (100 timesteps)
# Episode 363 finished. Total reward: 100.0 (100 timesteps)
# Episode 364 finished. Total reward: 100.0 (100 timesteps)
# Episode 365 finished. Total reward: 100.0 (100 timesteps)
# Episode 366 finished. Total reward: 100.0 (100 timesteps)
# Episode 367 finished. Total reward: 100.0 (100 timesteps)
# Episode 368 finished. Total reward: 100.0 (100 timesteps)
# Episode 369 finished. Total reward: 100.0 (100 timesteps)
# Episode 370 finished. Total reward: 100.0 (100 timesteps)
# Episode 371 finished. Total reward: 100.0 (100 timesteps)
# Episode 372 finished. Total reward: 100.0 (100 timesteps)
# Episode 373 finished. Total reward: 100.0 (100 timesteps)
# Episode 374 finished. Total reward: 100.0 (100 timesteps)
# Episode 375 finished. Total reward: 100.0 (100 timesteps)
# Episode 376 finished. Total reward: 100.0 (100 timesteps)
# Episode 377 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 378 finished. Total reward: 100.0 (100 timesteps)
# Episode 379 finished. Total reward: 44.0 (44 timesteps)
# Episode 380 finished. Total reward: 100.0 (100 timesteps)
# Episode 381 finished. Total reward: 100.0 (100 timesteps)
# Episode 382 finished. Total reward: 100.0 (100 timesteps)
# Episode 383 finished. Total reward: 100.0 (100 timesteps)
# Episode 384 finished. Total reward: 100.0 (100 timesteps)
# Episode 385 finished. Total reward: 100.0 (100 timesteps)
# Episode 386 finished. Total reward: 100.0 (100 timesteps)
# Episode 387 finished. Total reward: 100.0 (100 timesteps)
# Episode 388 finished. Total reward: 100.0 (100 timesteps)
# Episode 389 finished. Total reward: 100.0 (100 timesteps)
# Episode 390 finished. Total reward: 100.0 (100 timesteps)
# Episode 391 finished. Total reward: 69.0 (69 timesteps)
# Episode 392 finished. Total reward: 100.0 (100 timesteps)
# Episode 393 finished. Total reward: 100.0 (100 timesteps)
# Episode 394 finished. Total reward: 100.0 (100 timesteps)
# Episode 395 finished. Total reward: 100.0 (100 timesteps)
# Episode 396 finished. Total reward: 100.0 (100 timesteps)
# Episode 397 finished. Total reward: 83.0 (83 timesteps)
# Episode 398 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 399 finished. Total reward: 100.0 (100 timesteps)
# Episode 400 finished. Total reward: 100.0 (100 timesteps)
# Episode 401 finished. Total reward: 100.0 (100 timesteps)
# Episode 402 finished. Total reward: 100.0 (100 timesteps)
# Episode 403 finished. Total reward: 100.0 (100 timesteps)
# Episode 404 finished. Total reward: 100.0 (100 timesteps)
# Episode 405 finished. Total reward: 100.0 (100 timesteps)
# Episode 406 finished. Total reward: 100.0 (100 timesteps)
# Episode 407 finished. Total reward: 68.0 (68 timesteps)
# Episode 408 finished. Total reward: 100.0 (100 timesteps)
# Episode 409 finished. Total reward: 100.0 (100 timesteps)
# Episode 410 finished. Total reward: 100.0 (100 timesteps)
# Episode 411 finished. Total reward: 100.0 (100 timesteps)
# Episode 412 finished. Total reward: 100.0 (100 timesteps)
# Episode 413 finished. Total reward: 100.0 (100 timesteps)
# Episode 414 finished. Total reward: 100.0 (100 timesteps)
# Episode 415 finished. Total reward: 100.0 (100 timesteps)
# Episode 416 finished. Total reward: 100.0 (100 timesteps)
# Episode 417 finished. Total reward: 100.0 (100 timesteps)
# Episode 418 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 419 finished. Total reward: 100.0 (100 timesteps)
# Episode 420 finished. Total reward: 100.0 (100 timesteps)
# Episode 421 finished. Total reward: 100.0 (100 timesteps)
# Episode 422 finished. Total reward: 100.0 (100 timesteps)
# Episode 423 finished. Total reward: 100.0 (100 timesteps)
# Episode 424 finished. Total reward: 100.0 (100 timesteps)
# Episode 425 finished. Total reward: 100.0 (100 timesteps)
# Episode 426 finished. Total reward: 100.0 (100 timesteps)
# Episode 427 finished. Total reward: 100.0 (100 timesteps)
# Episode 428 finished. Total reward: 100.0 (100 timesteps)
# Episode 429 finished. Total reward: 100.0 (100 timesteps)
# Episode 430 finished. Total reward: 100.0 (100 timesteps)
# Episode 431 finished. Total reward: 27.0 (27 timesteps)
# Episode 432 finished. Total reward: 100.0 (100 timesteps)
# Episode 433 finished. Total reward: 20.0 (20 timesteps)
# Episode 434 finished. Total reward: 100.0 (100 timesteps)
# Episode 435 finished. Total reward: 100.0 (100 timesteps)
# Episode 436 finished. Total reward: 100.0 (100 timesteps)
# Episode 437 finished. Total reward: 100.0 (100 timesteps)
# Episode 438 finished. Total reward: 100.0 (100 timesteps)
# Episode 439 finished. Total reward: 100.0 (100 timesteps)
# Episode 440 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 441 finished. Total reward: 100.0 (100 timesteps)
# Episode 442 finished. Total reward: 44.0 (44 timesteps)
# Episode 443 finished. Total reward: 77.0 (77 timesteps)
# Episode 444 finished. Total reward: 100.0 (100 timesteps)
# Episode 445 finished. Total reward: 100.0 (100 timesteps)
# Episode 446 finished. Total reward: 100.0 (100 timesteps)
# Episode 447 finished. Total reward: 100.0 (100 timesteps)
# Episode 448 finished. Total reward: 100.0 (100 timesteps)
# Episode 449 finished. Total reward: 100.0 (100 timesteps)
# Episode 450 finished. Total reward: 100.0 (100 timesteps)
# Episode 451 finished. Total reward: 100.0 (100 timesteps)
# Episode 452 finished. Total reward: 100.0 (100 timesteps)
# Episode 453 finished. Total reward: 100.0 (100 timesteps)
# Episode 454 finished. Total reward: 100.0 (100 timesteps)
# Episode 455 finished. Total reward: 100.0 (100 timesteps)
# Episode 456 finished. Total reward: 100.0 (100 timesteps)
# Episode 457 finished. Total reward: 100.0 (100 timesteps)
# Episode 458 finished. Total reward: 100.0 (100 timesteps)
# Episode 459 finished. Total reward: 100.0 (100 timesteps)
# Episode 460 finished. Total reward: 100.0 (100 timesteps)
# Episode 461 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 462 finished. Total reward: 100.0 (100 timesteps)
# Episode 463 finished. Total reward: 100.0 (100 timesteps)
# Episode 464 finished. Total reward: 100.0 (100 timesteps)
# Episode 465 finished. Total reward: 100.0 (100 timesteps)
# Episode 466 finished. Total reward: 19.0 (19 timesteps)
# Episode 467 finished. Total reward: 100.0 (100 timesteps)
# Episode 468 finished. Total reward: 100.0 (100 timesteps)
# Episode 469 finished. Total reward: 100.0 (100 timesteps)
# Episode 470 finished. Total reward: 100.0 (100 timesteps)
# Episode 471 finished. Total reward: 100.0 (100 timesteps)
# Episode 472 finished. Total reward: 100.0 (100 timesteps)
# Episode 473 finished. Total reward: 100.0 (100 timesteps)
# Episode 474 finished. Total reward: 100.0 (100 timesteps)
# Episode 475 finished. Total reward: 100.0 (100 timesteps)
# Episode 476 finished. Total reward: 100.0 (100 timesteps)
# Episode 477 finished. Total reward: 100.0 (100 timesteps)
# Episode 478 finished. Total reward: 100.0 (100 timesteps)
# Episode 479 finished. Total reward: 100.0 (100 timesteps)
# Episode 480 finished. Total reward: 100.0 (100 timesteps)
# Episode 481 finished. Total reward: 100.0 (100 timesteps)
# Episode 482 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 483 finished. Total reward: 100.0 (100 timesteps)
# Episode 484 finished. Total reward: 100.0 (100 timesteps)
# Episode 485 finished. Total reward: 100.0 (100 timesteps)
# Episode 486 finished. Total reward: 100.0 (100 timesteps)
# Episode 487 finished. Total reward: 100.0 (100 timesteps)
# Episode 488 finished. Total reward: 100.0 (100 timesteps)
# Episode 489 finished. Total reward: 100.0 (100 timesteps)
# Episode 490 finished. Total reward: 100.0 (100 timesteps)
# Episode 491 finished. Total reward: 100.0 (100 timesteps)
# Episode 492 finished. Total reward: 100.0 (100 timesteps)
# Episode 493 finished. Total reward: 100.0 (100 timesteps)
# Episode 494 finished. Total reward: 100.0 (100 timesteps)
# Episode 495 finished. Total reward: 100.0 (100 timesteps)
# Episode 496 finished. Total reward: 100.0 (100 timesteps)
# Episode 497 finished. Total reward: 100.0 (100 timesteps)
# Episode 498 finished. Total reward: 100.0 (100 timesteps)
# Episode 499 finished. Total reward: 100.0 (100 timesteps)
# Episode 500 finished. Total reward: 100.0 (100 timesteps)
# Model saved to /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)

# %% [markdown]
# DOUBLE CLICK HERE TO EDIT, CLEAR THIS TEXT AND REPORT HERE

# %% [markdown]
# The command below will evaluate the trained model in 10 episodes and report the average reward (and episode length) for these 10 episodes.

# %%
t.test(episodes=10, 
       cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', 
       cfg_args=dict(testing=True, seed=None, max_episode_steps=1000, use_wandb=False)) ##设置为none 就会随机制定种子
# Out:
# Numpy/Torch/Random Seed:  501
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/CartPole-v1/test folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Test ep reward: 137.0 seed: 88
# Test ep reward: 127.0 seed: 672
# Test ep reward: 131.0 seed: 680
# Test ep reward: 127.0 seed: 592
# Test ep reward: 135.0 seed: 481
# Test ep reward: 137.0 seed: 78
# Test ep reward: 147.0 seed: 735
# Test ep reward: 156.0 seed: 852
# Test ep reward: 132.0 seed: 694
# Test ep reward: 126.0 seed: 965
# Average test reward: 135.5 episode length: 135.5
# wandb: ERROR Dropped streaming file chunk (see wandb/debug-internal.log)

# %% [markdown]
# DOUBLE CLICK HERE TO EDIT, CLEAR THIS TEXT AND REPORT HERE

# %% [markdown]
# The agent acting in the environment can be seen using the following command. Change the ```path``` to pick the episode you want to visualize. Bear in mind by default video saving for training is taken every 50 episodes.

# %%
# Train Result
video_dir = work_dir/'video'/'CartPole-v1'/'train'

# List all MP4 files in the directory
mp4_files = [file for file in os.listdir(video_dir) if file.endswith(".mp4")]
frame_colors = ['#FF5733', '#33FF57', '#5733FF', '#FFFF33', '#33FFFF', '#FF33FF']
# Display each MP4 file
for i, mp4_file in enumerate(mp4_files):
    video_path = os.path.join(video_dir, mp4_file)
    video = Video(video_path, embed=True, html_attributes="loop autoplay", width=200, height=100)
    frame_color = frame_colors[i % len(frame_colors)]
    video_frame = HTML(f'<div style="width: 200px; height: 100px;; border: 1px solid #FF5733;">{video._repr_html_()}</div>')
    print("test/",mp4_file)
    display(video_frame)
# Out:
# test/ ex1-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-50.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-100.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-150.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-200.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-250.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-300.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-350.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-400.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-450.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-500.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #FF5733;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>

# %%
# Test Result

video_dir = work_dir/'video'/'CartPole-v1'/'test'

# List all MP4 files in the directory
mp4_files = [file for file in os.listdir(video_dir) if file.endswith(".mp4")]
frame_colors = ['#FF5733', '#33FF57', '#5733FF', '#FFFF33', '#33FFFF', '#FF33FF']
# Display each MP4 file
for i, mp4_file in enumerate(mp4_files):
    video_path = os.path.join(video_dir, mp4_file)
    video = Video(video_path, embed=True, html_attributes="loop autoplay", width=200, height=100)
    frame_color = frame_colors[i % len(frame_colors)]
    video_frame = HTML(f'<div style="width: 200px; height: 100px;; border: 1px solid #5733FF;">{video._repr_html_()}</div>')
    print("test/",mp4_file)
    display(video_frame)
# Out:
# test/ ex1-episode-0.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-1.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-2.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-3.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-4.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-5.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-6.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-7.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-8.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>
# test/ ex1-episode-9.mp4
# <div style="width: 200px; height: 100px;; border: 1px solid #5733FF;"><video loop autoplay  width="200"  height="100">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video></div>

# %% [markdown]
# <a id='Q1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 1.1</b> Learning (10 points) </h3>
#
# Test the trained model from Task 1 five times with different random seeds. Did the same model, trained to balance for 100 timesteps, learn to always balance the pole for 1000 timesteps? Why/why not?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# No,trained to balcance for 100 steps don't mean it can balcance the pole for 1000 timesteps. Because it will be more situations in 1000 timesteps which never happened in
# 100 steps trained model. Although we use different seeds for random test,the lack of situation remains a problem.

# %% [markdown]
# <a id='T2'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 2.</b> Investigating Training Performance (10 points) </h3>
#
# Repeat the experiment in Task 1 five times, each time training the model from scratch with 100 timesteps and testing it for 1000 timesteps. Use a different seed number for each training/testing cycle. You can use the box below to write a small script to do this. Use the result textbox below to report the average test reward for each repeat.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# seed: 224 Average test reward: 137.0 episode length: 137.0
# seed: 865 Average test reward: 166.0 episode length: 166.0
# seed: 524 Average test reward: 136.0 episode length: 136.0
# seed: 989 Average test reward: 114.0 episode length: 114.0
# seed: 85 Average test reward: 150.0 episode length: 150.0

# %%
import random

# 设置随机种子
num_runs = 5

for run in range(num_runs):
    # 随机生成不同的种子
    seed = random.randint(1, 1000)
    test_seed = random.randint(1, 1000)
    t.train(cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml', cfg_args=dict(seed=seed, max_episode_steps=100))
    test_result = t.test(episodes=10,cfg_path=Path().cwd()/'cfg'/'cartpole_v1.yaml',
                        cfg_args=dict(testing=True, seed=test_seed, 
                        max_episode_steps=1000, use_wandb=False))
# Out:
# Numpy/Torch/Random Seed:  339
# wandb version 0.15.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/notebooks/rl2023/ex1/wandb/run-20230916_001248-whuhjt3i</code>
# Syncing run <strong><a href='https://wandb.ai/mayangle/rl_aalto/runs/whuhjt3i' target="_blank">ex1-CartPole-v1-339-1694812368</a></strong> to <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">https://wandb.ai/mayangle/rl_aalto</a>
#  View run at <a href='https://wandb.ai/mayangle/rl_aalto/runs/whuhjt3i' target="_blank">https://wandb.ai/mayangle/rl_aalto/runs/whuhjt3i</a>
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/CartPole-v1/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Configuration Settings: {'exp_name': 'ex1', 'seed': 339, 'env_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Episode 0 finished. Total reward: 27.0 (27 timesteps)
# Episode 1 finished. Total reward: 55.0 (55 timesteps)
# Episode 2 finished. Total reward: 13.0 (13 timesteps)
# Episode 3 finished. Total reward: 31.0 (31 timesteps)
# Episode 4 finished. Total reward: 15.0 (15 timesteps)
# Episode 5 finished. Total reward: 17.0 (17 timesteps)
# Episode 6 finished. Total reward: 26.0 (26 timesteps)
# Episode 7 finished. Total reward: 14.0 (14 timesteps)
# Episode 8 finished. Total reward: 10.0 (10 timesteps)
# Episode 9 finished. Total reward: 8.0 (8 timesteps)
# Episode 10 finished. Total reward: 33.0 (33 timesteps)
# Episode 11 finished. Total reward: 14.0 (14 timesteps)
# Episode 12 finished. Total reward: 10.0 (10 timesteps)
# Episode 13 finished. Total reward: 17.0 (17 timesteps)
# Episode 14 finished. Total reward: 14.0 (14 timesteps)
# Episode 15 finished. Total reward: 12.0 (12 timesteps)
# Episode 16 finished. Total reward: 12.0 (12 timesteps)
# Episode 17 finished. Total reward: 18.0 (18 timesteps)
# Episode 18 finished. Total reward: 14.0 (14 timesteps)
# Episode 19 finished. Total reward: 17.0 (17 timesteps)
# Episode 20 finished. Total reward: 21.0 (21 timesteps)
# Episode 21 finished. Total reward: 29.0 (29 timesteps)
# Episode 22 finished. Total reward: 40.0 (40 timesteps)
# Episode 23 finished. Total reward: 9.0 (9 timesteps)
# Episode 24 finished. Total reward: 22.0 (22 timesteps)
# Episode 25 finished. Total reward: 14.0 (14 timesteps)
# Episode 26 finished. Total reward: 38.0 (38 timesteps)
# Episode 27 finished. Total reward: 18.0 (18 timesteps)
# Episode 28 finished. Total reward: 12.0 (12 timesteps)
# Episode 29 finished. Total reward: 15.0 (15 timesteps)
# Episode 30 finished. Total reward: 24.0 (24 timesteps)
# Episode 31 finished. Total reward: 34.0 (34 timesteps)
# Episode 32 finished. Total reward: 16.0 (16 timesteps)
# Episode 33 finished. Total reward: 12.0 (12 timesteps)
# Episode 34 finished. Total reward: 17.0 (17 timesteps)
# Episode 35 finished. Total reward: 72.0 (72 timesteps)
# Episode 36 finished. Total reward: 37.0 (37 timesteps)
# Episode 37 finished. Total reward: 15.0 (15 timesteps)
# Episode 38 finished. Total reward: 11.0 (11 timesteps)
# Episode 39 finished. Total reward: 18.0 (18 timesteps)
# Episode 40 finished. Total reward: 50.0 (50 timesteps)
# Episode 41 finished. Total reward: 48.0 (48 timesteps)
# Episode 42 finished. Total reward: 16.0 (16 timesteps)
# Episode 43 finished. Total reward: 18.0 (18 timesteps)
# Episode 44 finished. Total reward: 12.0 (12 timesteps)
# Episode 45 finished. Total reward: 22.0 (22 timesteps)
# Episode 46 finished. Total reward: 13.0 (13 timesteps)
# Episode 47 finished. Total reward: 14.0 (14 timesteps)
# Episode 48 finished. Total reward: 25.0 (25 timesteps)
# Episode 49 finished. Total reward: 30.0 (30 timesteps)
# Episode 50 finished. Total reward: 17.0 (17 timesteps)
# Episode 51 finished. Total reward: 19.0 (19 timesteps)
# Episode 52 finished. Total reward: 49.0 (49 timesteps)
# Episode 53 finished. Total reward: 21.0 (21 timesteps)
# Episode 54 finished. Total reward: 27.0 (27 timesteps)
# Episode 55 finished. Total reward: 15.0 (15 timesteps)
# Episode 56 finished. Total reward: 34.0 (34 timesteps)
# Episode 57 finished. Total reward: 16.0 (16 timesteps)
# Episode 58 finished. Total reward: 10.0 (10 timesteps)
# Episode 59 finished. Total reward: 16.0 (16 timesteps)
# Episode 60 finished. Total reward: 17.0 (17 timesteps)
# Episode 61 finished. Total reward: 55.0 (55 timesteps)
# Episode 62 finished. Total reward: 20.0 (20 timesteps)
# Episode 63 finished. Total reward: 12.0 (12 timesteps)
# Episode 64 finished. Total reward: 31.0 (31 timesteps)
# Episode 65 finished. Total reward: 28.0 (28 timesteps)
# Episode 66 finished. Total reward: 22.0 (22 timesteps)
# Episode 67 finished. Total reward: 30.0 (30 timesteps)
# Episode 68 finished. Total reward: 15.0 (15 timesteps)
# Episode 69 finished. Total reward: 27.0 (27 timesteps)
# Episode 70 finished. Total reward: 10.0 (10 timesteps)
# Episode 71 finished. Total reward: 19.0 (19 timesteps)
# Episode 72 finished. Total reward: 14.0 (14 timesteps)
# Episode 73 finished. Total reward: 16.0 (16 timesteps)
# Episode 74 finished. Total reward: 16.0 (16 timesteps)
# Episode 75 finished. Total reward: 11.0 (11 timesteps)
# Episode 76 finished. Total reward: 29.0 (29 timesteps)
# Episode 77 finished. Total reward: 10.0 (10 timesteps)
# Episode 78 finished. Total reward: 21.0 (21 timesteps)
# Episode 79 finished. Total reward: 17.0 (17 timesteps)
# Episode 80 finished. Total reward: 12.0 (12 timesteps)
# Episode 81 finished. Total reward: 17.0 (17 timesteps)
# Episode 82 finished. Total reward: 33.0 (33 timesteps)
# Episode 83 finished. Total reward: 17.0 (17 timesteps)
# Episode 84 finished. Total reward: 14.0 (14 timesteps)
# Episode 85 finished. Total reward: 62.0 (62 timesteps)
# Episode 86 finished. Total reward: 27.0 (27 timesteps)
# Episode 87 finished. Total reward: 13.0 (13 timesteps)
# Episode 88 finished. Total reward: 49.0 (49 timesteps)
# Updating the policy...
# Updating finished!
# Episode 89 finished. Total reward: 39.0 (39 timesteps)
# Episode 90 finished. Total reward: 10.0 (10 timesteps)
# Episode 91 finished. Total reward: 17.0 (17 timesteps)
# Episode 92 finished. Total reward: 41.0 (41 timesteps)
# Episode 93 finished. Total reward: 21.0 (21 timesteps)
# Episode 94 finished. Total reward: 19.0 (19 timesteps)
# Episode 95 finished. Total reward: 11.0 (11 timesteps)
# Episode 96 finished. Total reward: 32.0 (32 timesteps)
# Episode 97 finished. Total reward: 31.0 (31 timesteps)
# Episode 98 finished. Total reward: 33.0 (33 timesteps)
# Episode 99 finished. Total reward: 25.0 (25 timesteps)
# Episode 100 finished. Total reward: 61.0 (61 timesteps)
# Episode 101 finished. Total reward: 17.0 (17 timesteps)
# Episode 102 finished. Total reward: 21.0 (21 timesteps)
# Episode 103 finished. Total reward: 22.0 (22 timesteps)
# Episode 104 finished. Total reward: 100.0 (100 timesteps)
# Episode 105 finished. Total reward: 15.0 (15 timesteps)
# Episode 106 finished. Total reward: 16.0 (16 timesteps)
# Episode 107 finished. Total reward: 31.0 (31 timesteps)
# Episode 108 finished. Total reward: 23.0 (23 timesteps)
# Episode 109 finished. Total reward: 11.0 (11 timesteps)
# Episode 110 finished. Total reward: 14.0 (14 timesteps)
# Episode 111 finished. Total reward: 30.0 (30 timesteps)
# Episode 112 finished. Total reward: 18.0 (18 timesteps)
# Episode 113 finished. Total reward: 15.0 (15 timesteps)
# Episode 114 finished. Total reward: 15.0 (15 timesteps)
# Episode 115 finished. Total reward: 35.0 (35 timesteps)
# Episode 116 finished. Total reward: 17.0 (17 timesteps)
# Episode 117 finished. Total reward: 15.0 (15 timesteps)
# Episode 118 finished. Total reward: 13.0 (13 timesteps)
# Episode 119 finished. Total reward: 24.0 (24 timesteps)
# Episode 120 finished. Total reward: 22.0 (22 timesteps)
# Episode 121 finished. Total reward: 61.0 (61 timesteps)
# Episode 122 finished. Total reward: 13.0 (13 timesteps)
# Episode 123 finished. Total reward: 17.0 (17 timesteps)
# Episode 124 finished. Total reward: 22.0 (22 timesteps)
# Episode 125 finished. Total reward: 40.0 (40 timesteps)
# Episode 126 finished. Total reward: 16.0 (16 timesteps)
# Episode 127 finished. Total reward: 31.0 (31 timesteps)
# Episode 128 finished. Total reward: 22.0 (22 timesteps)
# Episode 129 finished. Total reward: 28.0 (28 timesteps)
# Episode 130 finished. Total reward: 35.0 (35 timesteps)
# Episode 131 finished. Total reward: 22.0 (22 timesteps)
# Episode 132 finished. Total reward: 19.0 (19 timesteps)
# Episode 133 finished. Total reward: 13.0 (13 timesteps)
# Episode 134 finished. Total reward: 14.0 (14 timesteps)
# Episode 135 finished. Total reward: 61.0 (61 timesteps)
# Episode 136 finished. Total reward: 34.0 (34 timesteps)
# Episode 137 finished. Total reward: 19.0 (19 timesteps)
# Episode 138 finished. Total reward: 15.0 (15 timesteps)
# Episode 139 finished. Total reward: 11.0 (11 timesteps)
# Episode 140 finished. Total reward: 20.0 (20 timesteps)
# Episode 141 finished. Total reward: 12.0 (12 timesteps)
# Episode 142 finished. Total reward: 13.0 (13 timesteps)
# Episode 143 finished. Total reward: 35.0 (35 timesteps)
# Episode 144 finished. Total reward: 25.0 (25 timesteps)
# Episode 145 finished. Total reward: 19.0 (19 timesteps)
# Episode 146 finished. Total reward: 14.0 (14 timesteps)
# Episode 147 finished. Total reward: 50.0 (50 timesteps)
# Episode 148 finished. Total reward: 30.0 (30 timesteps)
# Episode 149 finished. Total reward: 26.0 (26 timesteps)
# Episode 150 finished. Total reward: 15.0 (15 timesteps)
# Episode 151 finished. Total reward: 28.0 (28 timesteps)
# Episode 152 finished. Total reward: 17.0 (17 timesteps)
# Episode 153 finished. Total reward: 16.0 (16 timesteps)
# Episode 154 finished. Total reward: 50.0 (50 timesteps)
# Episode 155 finished. Total reward: 11.0 (11 timesteps)
# Episode 156 finished. Total reward: 11.0 (11 timesteps)
# Episode 157 finished. Total reward: 18.0 (18 timesteps)
# Episode 158 finished. Total reward: 54.0 (54 timesteps)
# Episode 159 finished. Total reward: 24.0 (24 timesteps)
# Episode 160 finished. Total reward: 24.0 (24 timesteps)
# Episode 161 finished. Total reward: 26.0 (26 timesteps)
# Episode 162 finished. Total reward: 20.0 (20 timesteps)
# Episode 163 finished. Total reward: 26.0 (26 timesteps)
# Episode 164 finished. Total reward: 17.0 (17 timesteps)
# Episode 165 finished. Total reward: 23.0 (23 timesteps)
# Episode 166 finished. Total reward: 14.0 (14 timesteps)
# Episode 167 finished. Total reward: 18.0 (18 timesteps)
# Episode 168 finished. Total reward: 16.0 (16 timesteps)
# Updating the policy...
# Updating finished!
# Episode 169 finished. Total reward: 40.0 (40 timesteps)
# Episode 170 finished. Total reward: 21.0 (21 timesteps)
# Episode 171 finished. Total reward: 31.0 (31 timesteps)
# Episode 172 finished. Total reward: 27.0 (27 timesteps)
# Episode 173 finished. Total reward: 16.0 (16 timesteps)
# Episode 174 finished. Total reward: 25.0 (25 timesteps)
# Episode 175 finished. Total reward: 26.0 (26 timesteps)
# Episode 176 finished. Total reward: 19.0 (19 timesteps)
# Episode 177 finished. Total reward: 42.0 (42 timesteps)
# Episode 178 finished. Total reward: 26.0 (26 timesteps)
# Episode 179 finished. Total reward: 21.0 (21 timesteps)
# Episode 180 finished. Total reward: 36.0 (36 timesteps)
# Episode 181 finished. Total reward: 31.0 (31 timesteps)
# Episode 182 finished. Total reward: 15.0 (15 timesteps)
# Episode 183 finished. Total reward: 22.0 (22 timesteps)
# Episode 184 finished. Total reward: 11.0 (11 timesteps)
# Episode 185 finished. Total reward: 77.0 (77 timesteps)
# Episode 186 finished. Total reward: 87.0 (87 timesteps)
# Episode 187 finished. Total reward: 22.0 (22 timesteps)
# Episode 188 finished. Total reward: 14.0 (14 timesteps)
# Episode 189 finished. Total reward: 40.0 (40 timesteps)
# Episode 190 finished. Total reward: 21.0 (21 timesteps)
# Episode 191 finished. Total reward: 32.0 (32 timesteps)
# Episode 192 finished. Total reward: 21.0 (21 timesteps)
# Episode 193 finished. Total reward: 55.0 (55 timesteps)
# Episode 194 finished. Total reward: 21.0 (21 timesteps)
# Episode 195 finished. Total reward: 18.0 (18 timesteps)
# Episode 196 finished. Total reward: 33.0 (33 timesteps)
# Episode 197 finished. Total reward: 46.0 (46 timesteps)
# Episode 198 finished. Total reward: 28.0 (28 timesteps)
# Episode 199 finished. Total reward: 14.0 (14 timesteps)
# Episode 200 finished. Total reward: 100.0 (100 timesteps)
# Episode 201 finished. Total reward: 26.0 (26 timesteps)
# Episode 202 finished. Total reward: 100.0 (100 timesteps)
# Episode 203 finished. Total reward: 24.0 (24 timesteps)
# Episode 204 finished. Total reward: 16.0 (16 timesteps)
# Episode 205 finished. Total reward: 100.0 (100 timesteps)
# Episode 206 finished. Total reward: 70.0 (70 timesteps)
# Episode 207 finished. Total reward: 21.0 (21 timesteps)
# Episode 208 finished. Total reward: 27.0 (27 timesteps)
# Episode 209 finished. Total reward: 35.0 (35 timesteps)
# Episode 210 finished. Total reward: 52.0 (52 timesteps)
# Episode 211 finished. Total reward: 18.0 (18 timesteps)
# Episode 212 finished. Total reward: 16.0 (16 timesteps)
# Episode 213 finished. Total reward: 71.0 (71 timesteps)
# Episode 214 finished. Total reward: 84.0 (84 timesteps)
# Episode 215 finished. Total reward: 82.0 (82 timesteps)
# Episode 216 finished. Total reward: 23.0 (23 timesteps)
# Episode 217 finished. Total reward: 61.0 (61 timesteps)
# Episode 218 finished. Total reward: 35.0 (35 timesteps)
# Episode 219 finished. Total reward: 51.0 (51 timesteps)
# Episode 220 finished. Total reward: 13.0 (13 timesteps)
# Updating the policy...
# Updating finished!
# Episode 221 finished. Total reward: 75.0 (75 timesteps)
# Episode 222 finished. Total reward: 100.0 (100 timesteps)
# Episode 223 finished. Total reward: 13.0 (13 timesteps)
# Episode 224 finished. Total reward: 98.0 (98 timesteps)
# Episode 225 finished. Total reward: 36.0 (36 timesteps)
# Episode 226 finished. Total reward: 66.0 (66 timesteps)
# Episode 227 finished. Total reward: 61.0 (61 timesteps)
# Episode 228 finished. Total reward: 17.0 (17 timesteps)
# Episode 229 finished. Total reward: 35.0 (35 timesteps)
# Episode 230 finished. Total reward: 19.0 (19 timesteps)
# Episode 231 finished. Total reward: 37.0 (37 timesteps)
# Episode 232 finished. Total reward: 26.0 (26 timesteps)
# Episode 233 finished. Total reward: 50.0 (50 timesteps)
# Episode 234 finished. Total reward: 35.0 (35 timesteps)
# Episode 235 finished. Total reward: 98.0 (98 timesteps)
# Episode 236 finished. Total reward: 76.0 (76 timesteps)
# Episode 237 finished. Total reward: 100.0 (100 timesteps)
# Episode 238 finished. Total reward: 58.0 (58 timesteps)
# Episode 239 finished. Total reward: 33.0 (33 timesteps)
# Episode 240 finished. Total reward: 41.0 (41 timesteps)
# Episode 241 finished. Total reward: 100.0 (100 timesteps)
# Episode 242 finished. Total reward: 74.0 (74 timesteps)
# Episode 243 finished. Total reward: 100.0 (100 timesteps)
# Episode 244 finished. Total reward: 15.0 (15 timesteps)
# Episode 245 finished. Total reward: 22.0 (22 timesteps)
# Episode 246 finished. Total reward: 44.0 (44 timesteps)
# Episode 247 finished. Total reward: 34.0 (34 timesteps)
# Episode 248 finished. Total reward: 15.0 (15 timesteps)
# Episode 249 finished. Total reward: 92.0 (92 timesteps)
# Episode 250 finished. Total reward: 100.0 (100 timesteps)
# Episode 251 finished. Total reward: 100.0 (100 timesteps)
# Episode 252 finished. Total reward: 29.0 (29 timesteps)
# Episode 253 finished. Total reward: 100.0 (100 timesteps)
# Episode 254 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 255 finished. Total reward: 100.0 (100 timesteps)
# Episode 256 finished. Total reward: 100.0 (100 timesteps)
# Episode 257 finished. Total reward: 100.0 (100 timesteps)
# Episode 258 finished. Total reward: 100.0 (100 timesteps)
# Episode 259 finished. Total reward: 99.0 (99 timesteps)
# Episode 260 finished. Total reward: 100.0 (100 timesteps)
# Episode 261 finished. Total reward: 58.0 (58 timesteps)
# Episode 262 finished. Total reward: 100.0 (100 timesteps)
# Episode 263 finished. Total reward: 100.0 (100 timesteps)
# Episode 264 finished. Total reward: 16.0 (16 timesteps)
# Episode 265 finished. Total reward: 52.0 (52 timesteps)
# Episode 266 finished. Total reward: 100.0 (100 timesteps)
# Episode 267 finished. Total reward: 100.0 (100 timesteps)
# Episode 268 finished. Total reward: 75.0 (75 timesteps)
# Episode 269 finished. Total reward: 100.0 (100 timesteps)
# Episode 270 finished. Total reward: 53.0 (53 timesteps)
# Episode 271 finished. Total reward: 100.0 (100 timesteps)
# Episode 272 finished. Total reward: 30.0 (30 timesteps)
# Episode 273 finished. Total reward: 65.0 (65 timesteps)
# Episode 274 finished. Total reward: 46.0 (46 timesteps)
# Episode 275 finished. Total reward: 100.0 (100 timesteps)
# Episode 276 finished. Total reward: 82.0 (82 timesteps)
# Episode 277 finished. Total reward: 100.0 (100 timesteps)
# Episode 278 finished. Total reward: 87.0 (87 timesteps)
# Episode 279 finished. Total reward: 91.0 (91 timesteps)
# Updating the policy...
# Updating finished!
# Episode 280 finished. Total reward: 99.0 (99 timesteps)
# Episode 281 finished. Total reward: 100.0 (100 timesteps)
# Episode 282 finished. Total reward: 100.0 (100 timesteps)
# Episode 283 finished. Total reward: 100.0 (100 timesteps)
# Episode 284 finished. Total reward: 100.0 (100 timesteps)
# Episode 285 finished. Total reward: 66.0 (66 timesteps)
# Episode 286 finished. Total reward: 100.0 (100 timesteps)
# Episode 287 finished. Total reward: 100.0 (100 timesteps)
# Episode 288 finished. Total reward: 52.0 (52 timesteps)
# Episode 289 finished. Total reward: 100.0 (100 timesteps)
# Episode 290 finished. Total reward: 100.0 (100 timesteps)
# Episode 291 finished. Total reward: 100.0 (100 timesteps)
# Episode 292 finished. Total reward: 100.0 (100 timesteps)
# Episode 293 finished. Total reward: 100.0 (100 timesteps)
# Episode 294 finished. Total reward: 100.0 (100 timesteps)
# Episode 295 finished. Total reward: 100.0 (100 timesteps)
# Episode 296 finished. Total reward: 100.0 (100 timesteps)
# Episode 297 finished. Total reward: 75.0 (75 timesteps)
# Episode 298 finished. Total reward: 100.0 (100 timesteps)
# Episode 299 finished. Total reward: 39.0 (39 timesteps)
# Episode 300 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 301 finished. Total reward: 100.0 (100 timesteps)
# Episode 302 finished. Total reward: 100.0 (100 timesteps)
# Episode 303 finished. Total reward: 31.0 (31 timesteps)
# Episode 304 finished. Total reward: 100.0 (100 timesteps)
# Episode 305 finished. Total reward: 40.0 (40 timesteps)
# Episode 306 finished. Total reward: 100.0 (100 timesteps)
# Episode 307 finished. Total reward: 93.0 (93 timesteps)
# Episode 308 finished. Total reward: 100.0 (100 timesteps)
# Episode 309 finished. Total reward: 100.0 (100 timesteps)
# Episode 310 finished. Total reward: 100.0 (100 timesteps)
# Episode 311 finished. Total reward: 100.0 (100 timesteps)
# Episode 312 finished. Total reward: 100.0 (100 timesteps)
# Episode 313 finished. Total reward: 100.0 (100 timesteps)
# Episode 314 finished. Total reward: 100.0 (100 timesteps)
# Episode 315 finished. Total reward: 100.0 (100 timesteps)
# Episode 316 finished. Total reward: 100.0 (100 timesteps)
# Episode 317 finished. Total reward: 100.0 (100 timesteps)
# Episode 318 finished. Total reward: 100.0 (100 timesteps)
# Episode 319 finished. Total reward: 22.0 (22 timesteps)
# Episode 320 finished. Total reward: 100.0 (100 timesteps)
# Episode 321 finished. Total reward: 100.0 (100 timesteps)
# Episode 322 finished. Total reward: 100.0 (100 timesteps)
# Episode 323 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 324 finished. Total reward: 100.0 (100 timesteps)
# Episode 325 finished. Total reward: 100.0 (100 timesteps)
# Episode 326 finished. Total reward: 100.0 (100 timesteps)
# Episode 327 finished. Total reward: 64.0 (64 timesteps)
# Episode 328 finished. Total reward: 100.0 (100 timesteps)
# Episode 329 finished. Total reward: 100.0 (100 timesteps)
# Episode 330 finished. Total reward: 100.0 (100 timesteps)
# Episode 331 finished. Total reward: 100.0 (100 timesteps)
# Episode 332 finished. Total reward: 100.0 (100 timesteps)
# Episode 333 finished. Total reward: 100.0 (100 timesteps)
# Episode 334 finished. Total reward: 100.0 (100 timesteps)
# Episode 335 finished. Total reward: 100.0 (100 timesteps)
# Episode 336 finished. Total reward: 100.0 (100 timesteps)
# Episode 337 finished. Total reward: 100.0 (100 timesteps)
# Episode 338 finished. Total reward: 100.0 (100 timesteps)
# Episode 339 finished. Total reward: 100.0 (100 timesteps)
# Episode 340 finished. Total reward: 100.0 (100 timesteps)
# Episode 341 finished. Total reward: 82.0 (82 timesteps)
# Episode 342 finished. Total reward: 100.0 (100 timesteps)
# Episode 343 finished. Total reward: 34.0 (34 timesteps)
# Episode 344 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 345 finished. Total reward: 100.0 (100 timesteps)
# Episode 346 finished. Total reward: 100.0 (100 timesteps)
# Episode 347 finished. Total reward: 100.0 (100 timesteps)
# Episode 348 finished. Total reward: 42.0 (42 timesteps)
# Episode 349 finished. Total reward: 100.0 (100 timesteps)
# Episode 350 finished. Total reward: 100.0 (100 timesteps)
# Episode 351 finished. Total reward: 94.0 (94 timesteps)
# Episode 352 finished. Total reward: 25.0 (25 timesteps)
# Episode 353 finished. Total reward: 100.0 (100 timesteps)
# Episode 354 finished. Total reward: 100.0 (100 timesteps)
# Episode 355 finished. Total reward: 100.0 (100 timesteps)
# Episode 356 finished. Total reward: 100.0 (100 timesteps)
# Episode 357 finished. Total reward: 100.0 (100 timesteps)
# Episode 358 finished. Total reward: 34.0 (34 timesteps)
# Episode 359 finished. Total reward: 100.0 (100 timesteps)
# Episode 360 finished. Total reward: 91.0 (91 timesteps)
# Episode 361 finished. Total reward: 44.0 (44 timesteps)
# Episode 362 finished. Total reward: 100.0 (100 timesteps)
# Episode 363 finished. Total reward: 100.0 (100 timesteps)
# Episode 364 finished. Total reward: 100.0 (100 timesteps)
# Episode 365 finished. Total reward: 100.0 (100 timesteps)
# Episode 366 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 367 finished. Total reward: 100.0 (100 timesteps)
# Episode 368 finished. Total reward: 100.0 (100 timesteps)
# Episode 369 finished. Total reward: 100.0 (100 timesteps)
# Episode 370 finished. Total reward: 100.0 (100 timesteps)
# Episode 371 finished. Total reward: 100.0 (100 timesteps)
# Episode 372 finished. Total reward: 100.0 (100 timesteps)
# Episode 373 finished. Total reward: 84.0 (84 timesteps)
# Episode 374 finished. Total reward: 100.0 (100 timesteps)
# Episode 375 finished. Total reward: 100.0 (100 timesteps)
# Episode 376 finished. Total reward: 100.0 (100 timesteps)
# Episode 377 finished. Total reward: 100.0 (100 timesteps)
# Episode 378 finished. Total reward: 100.0 (100 timesteps)
# Episode 379 finished. Total reward: 100.0 (100 timesteps)
# Episode 380 finished. Total reward: 100.0 (100 timesteps)
# Episode 381 finished. Total reward: 100.0 (100 timesteps)
# Episode 382 finished. Total reward: 100.0 (100 timesteps)
# Episode 383 finished. Total reward: 100.0 (100 timesteps)
# Episode 384 finished. Total reward: 100.0 (100 timesteps)
# Episode 385 finished. Total reward: 100.0 (100 timesteps)
# Episode 386 finished. Total reward: 100.0 (100 timesteps)
# Episode 387 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 388 finished. Total reward: 100.0 (100 timesteps)
# Episode 389 finished. Total reward: 100.0 (100 timesteps)
# Episode 390 finished. Total reward: 100.0 (100 timesteps)
# Episode 391 finished. Total reward: 100.0 (100 timesteps)
# Episode 392 finished. Total reward: 100.0 (100 timesteps)
# Episode 393 finished. Total reward: 89.0 (89 timesteps)
# Episode 394 finished. Total reward: 100.0 (100 timesteps)
# Episode 395 finished. Total reward: 83.0 (83 timesteps)
# Episode 396 finished. Total reward: 100.0 (100 timesteps)
# Episode 397 finished. Total reward: 100.0 (100 timesteps)
# Episode 398 finished. Total reward: 100.0 (100 timesteps)
# Episode 399 finished. Total reward: 100.0 (100 timesteps)
# Episode 400 finished. Total reward: 87.0 (87 timesteps)
# Episode 401 finished. Total reward: 100.0 (100 timesteps)
# Episode 402 finished. Total reward: 100.0 (100 timesteps)
# Episode 403 finished. Total reward: 100.0 (100 timesteps)
# Episode 404 finished. Total reward: 100.0 (100 timesteps)
# Episode 405 finished. Total reward: 100.0 (100 timesteps)
# Episode 406 finished. Total reward: 100.0 (100 timesteps)
# Episode 407 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 408 finished. Total reward: 89.0 (89 timesteps)
# Episode 409 finished. Total reward: 100.0 (100 timesteps)
# Episode 410 finished. Total reward: 90.0 (90 timesteps)
# Episode 411 finished. Total reward: 100.0 (100 timesteps)
# Episode 412 finished. Total reward: 100.0 (100 timesteps)
# Episode 413 finished. Total reward: 100.0 (100 timesteps)
# Episode 414 finished. Total reward: 100.0 (100 timesteps)
# Episode 415 finished. Total reward: 100.0 (100 timesteps)
# Episode 416 finished. Total reward: 100.0 (100 timesteps)
# Episode 417 finished. Total reward: 100.0 (100 timesteps)
# Episode 418 finished. Total reward: 100.0 (100 timesteps)
# Episode 419 finished. Total reward: 100.0 (100 timesteps)
# Episode 420 finished. Total reward: 100.0 (100 timesteps)
# Episode 421 finished. Total reward: 100.0 (100 timesteps)
# Episode 422 finished. Total reward: 100.0 (100 timesteps)
# Episode 423 finished. Total reward: 100.0 (100 timesteps)
# Episode 424 finished. Total reward: 100.0 (100 timesteps)
# Episode 425 finished. Total reward: 100.0 (100 timesteps)
# Episode 426 finished. Total reward: 100.0 (100 timesteps)
# Episode 427 finished. Total reward: 100.0 (100 timesteps)
# Episode 428 finished. Total reward: 49.0 (49 timesteps)
# Updating the policy...
# Updating finished!
# Episode 429 finished. Total reward: 100.0 (100 timesteps)
# Episode 430 finished. Total reward: 100.0 (100 timesteps)
# Episode 431 finished. Total reward: 100.0 (100 timesteps)
# Episode 432 finished. Total reward: 100.0 (100 timesteps)
# Episode 433 finished. Total reward: 100.0 (100 timesteps)
# Episode 434 finished. Total reward: 100.0 (100 timesteps)
# Episode 435 finished. Total reward: 100.0 (100 timesteps)
# Episode 436 finished. Total reward: 100.0 (100 timesteps)
# Episode 437 finished. Total reward: 100.0 (100 timesteps)
# Episode 438 finished. Total reward: 100.0 (100 timesteps)
# Episode 439 finished. Total reward: 100.0 (100 timesteps)
# Episode 440 finished. Total reward: 100.0 (100 timesteps)
# Episode 441 finished. Total reward: 100.0 (100 timesteps)
# Episode 442 finished. Total reward: 100.0 (100 timesteps)
# Episode 443 finished. Total reward: 100.0 (100 timesteps)
# Episode 444 finished. Total reward: 100.0 (100 timesteps)
# Episode 445 finished. Total reward: 100.0 (100 timesteps)
# Episode 446 finished. Total reward: 100.0 (100 timesteps)
# Episode 447 finished. Total reward: 100.0 (100 timesteps)
# Episode 448 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 449 finished. Total reward: 100.0 (100 timesteps)
# Episode 450 finished. Total reward: 100.0 (100 timesteps)
# Episode 451 finished. Total reward: 100.0 (100 timesteps)
# Episode 452 finished. Total reward: 100.0 (100 timesteps)
# Episode 453 finished. Total reward: 100.0 (100 timesteps)
# Episode 454 finished. Total reward: 100.0 (100 timesteps)
# Episode 455 finished. Total reward: 100.0 (100 timesteps)
# Episode 456 finished. Total reward: 100.0 (100 timesteps)
# Episode 457 finished. Total reward: 100.0 (100 timesteps)
# Episode 458 finished. Total reward: 100.0 (100 timesteps)
# Episode 459 finished. Total reward: 100.0 (100 timesteps)
# Episode 460 finished. Total reward: 100.0 (100 timesteps)
# Episode 461 finished. Total reward: 100.0 (100 timesteps)
# Episode 462 finished. Total reward: 100.0 (100 timesteps)
# Episode 463 finished. Total reward: 100.0 (100 timesteps)
# Episode 464 finished. Total reward: 100.0 (100 timesteps)
# Episode 465 finished. Total reward: 100.0 (100 timesteps)
# Episode 466 finished. Total reward: 100.0 (100 timesteps)
# Episode 467 finished. Total reward: 100.0 (100 timesteps)
# Episode 468 finished. Total reward: 74.0 (74 timesteps)
# Updating the policy...
# Updating finished!
# Episode 469 finished. Total reward: 100.0 (100 timesteps)
# Episode 470 finished. Total reward: 100.0 (100 timesteps)
# Episode 471 finished. Total reward: 100.0 (100 timesteps)
# Episode 472 finished. Total reward: 100.0 (100 timesteps)
# Episode 473 finished. Total reward: 100.0 (100 timesteps)
# Episode 474 finished. Total reward: 100.0 (100 timesteps)
# Episode 475 finished. Total reward: 100.0 (100 timesteps)
# Episode 476 finished. Total reward: 89.0 (89 timesteps)
# Episode 477 finished. Total reward: 96.0 (96 timesteps)
# Episode 478 finished. Total reward: 100.0 (100 timesteps)
# Episode 479 finished. Total reward: 100.0 (100 timesteps)
# Episode 480 finished. Total reward: 100.0 (100 timesteps)
# Episode 481 finished. Total reward: 100.0 (100 timesteps)
# Episode 482 finished. Total reward: 100.0 (100 timesteps)
# Episode 483 finished. Total reward: 100.0 (100 timesteps)
# Episode 484 finished. Total reward: 100.0 (100 timesteps)
# Episode 485 finished. Total reward: 100.0 (100 timesteps)
# Episode 486 finished. Total reward: 100.0 (100 timesteps)
# Episode 487 finished. Total reward: 100.0 (100 timesteps)
# Episode 488 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 489 finished. Total reward: 100.0 (100 timesteps)
# Episode 490 finished. Total reward: 100.0 (100 timesteps)
# Episode 491 finished. Total reward: 100.0 (100 timesteps)
# Episode 492 finished. Total reward: 100.0 (100 timesteps)
# Episode 493 finished. Total reward: 100.0 (100 timesteps)
# Episode 494 finished. Total reward: 100.0 (100 timesteps)
# Episode 495 finished. Total reward: 100.0 (100 timesteps)
# Episode 496 finished. Total reward: 100.0 (100 timesteps)
# Episode 497 finished. Total reward: 100.0 (100 timesteps)
# Episode 498 finished. Total reward: 100.0 (100 timesteps)
# Episode 499 finished. Total reward: 100.0 (100 timesteps)
# Episode 500 finished. Total reward: 100.0 (100 timesteps)
# Model saved to /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  224
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/CartPole-v1/test folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Test ep reward: 137.0 seed: 224
# Test ep reward: 137.0 seed: 224
# Test ep reward: 137.0 seed: 224
# Test ep reward: 137.0 seed: 224
# Test ep reward: 137.0 seed: 224
# Test ep reward: 137.0 seed: 224
# Test ep reward: 137.0 seed: 224
# Test ep reward: 137.0 seed: 224
# Test ep reward: 137.0 seed: 224
# Test ep reward: 137.0 seed: 224
# Average test reward: 137.0 episode length: 137.0
# Numpy/Torch/Random Seed:  66
# Finishing last run (ID:whuhjt3i) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.037 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.063748…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>▃▁▂▂▂▁▁▁▂▃▃▁▁▂▂▃▂▄▃███▇█▇▂█▃███▇████████</td></tr><tr><td>episodes</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>num_updates</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>timesteps</td><td>▃▁▂▂▂▁▁▁▂▃▃▁▁▂▂▃▂▄▃███▇█▇▂█▃███▇████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>100.0</td></tr><tr><td>episodes</td><td>500</td></tr><tr><td>num_updates</td><td>0</td></tr><tr><td>timesteps</td><td>100</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ex1-CartPole-v1-339-1694812368</strong> at: <a href='https://wandb.ai/mayangle/rl_aalto/runs/whuhjt3i' target="_blank">https://wandb.ai/mayangle/rl_aalto/runs/whuhjt3i</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230916_001248-whuhjt3i/logs</code>
# Successfully finished last run (ID:whuhjt3i). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666912076373895, max=1.0)…
# wandb version 0.15.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/notebooks/rl2023/ex1/wandb/run-20230916_001625-y4tbapss</code>
# Syncing run <strong><a href='https://wandb.ai/mayangle/rl_aalto/runs/y4tbapss' target="_blank">ex1-CartPole-v1-66-1694812585</a></strong> to <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">https://wandb.ai/mayangle/rl_aalto</a>
#  View run at <a href='https://wandb.ai/mayangle/rl_aalto/runs/y4tbapss' target="_blank">https://wandb.ai/mayangle/rl_aalto/runs/y4tbapss</a>
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/CartPole-v1/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Configuration Settings: {'exp_name': 'ex1', 'seed': 66, 'env_name': 'CartPole-v1', 'max_episode_steps': 100, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 4
# Action space dimensions: 2
#
# Episode 0 finished. Total reward: 13.0 (13 timesteps)
# Episode 1 finished. Total reward: 18.0 (18 timesteps)
# Episode 2 finished. Total reward: 18.0 (18 timesteps)
# Episode 3 finished. Total reward: 32.0 (32 timesteps)
# Episode 4 finished. Total reward: 16.0 (16 timesteps)
# Episode 5 finished. Total reward: 10.0 (10 timesteps)
# Episode 6 finished. Total reward: 9.0 (9 timesteps)
# Episode 7 finished. Total reward: 17.0 (17 timesteps)
# Episode 8 finished. Total reward: 14.0 (14 timesteps)
# Episode 9 finished. Total reward: 20.0 (20 timesteps)
# Episode 10 finished. Total reward: 12.0 (12 timesteps)
# Episode 11 finished. Total reward: 15.0 (15 timesteps)
# Episode 12 finished. Total reward: 26.0 (26 timesteps)
# Episode 13 finished. Total reward: 9.0 (9 timesteps)
# Episode 14 finished. Total reward: 27.0 (27 timesteps)
# Episode 15 finished. Total reward: 14.0 (14 timesteps)
# Episode 16 finished. Total reward: 29.0 (29 timesteps)
# Episode 17 finished. Total reward: 18.0 (18 timesteps)
# Episode 18 finished. Total reward: 38.0 (38 timesteps)
# Episode 19 finished. Total reward: 49.0 (49 timesteps)
# Episode 20 finished. Total reward: 17.0 (17 timesteps)
# Episode 21 finished. Total reward: 67.0 (67 timesteps)
# Episode 22 finished. Total reward: 16.0 (16 timesteps)
# Episode 23 finished. Total reward: 20.0 (20 timesteps)
# Episode 24 finished. Total reward: 12.0 (12 timesteps)
# Episode 25 finished. Total reward: 18.0 (18 timesteps)
# Episode 26 finished. Total reward: 31.0 (31 timesteps)
# Episode 27 finished. Total reward: 14.0 (14 timesteps)
# Episode 28 finished. Total reward: 9.0 (9 timesteps)
# Episode 29 finished. Total reward: 16.0 (16 timesteps)
# Episode 30 finished. Total reward: 42.0 (42 timesteps)
# Episode 31 finished. Total reward: 9.0 (9 timesteps)
# Episode 32 finished. Total reward: 17.0 (17 timesteps)
# Episode 33 finished. Total reward: 27.0 (27 timesteps)
# Episode 34 finished. Total reward: 17.0 (17 timesteps)
# Episode 35 finished. Total reward: 10.0 (10 timesteps)
# Episode 36 finished. Total reward: 26.0 (26 timesteps)
# Episode 37 finished. Total reward: 14.0 (14 timesteps)
# Episode 38 finished. Total reward: 30.0 (30 timesteps)
# Episode 39 finished. Total reward: 37.0 (37 timesteps)
# Episode 40 finished. Total reward: 24.0 (24 timesteps)
# Episode 41 finished. Total reward: 24.0 (24 timesteps)
# Episode 42 finished. Total reward: 18.0 (18 timesteps)
# Episode 43 finished. Total reward: 13.0 (13 timesteps)
# Episode 44 finished. Total reward: 17.0 (17 timesteps)
# Episode 45 finished. Total reward: 14.0 (14 timesteps)
# Episode 46 finished. Total reward: 23.0 (23 timesteps)
# Episode 47 finished. Total reward: 34.0 (34 timesteps)
# Episode 48 finished. Total reward: 49.0 (49 timesteps)
# Episode 49 finished. Total reward: 21.0 (21 timesteps)
# Episode 50 finished. Total reward: 15.0 (15 timesteps)
# Episode 51 finished. Total reward: 17.0 (17 timesteps)
# Episode 52 finished. Total reward: 23.0 (23 timesteps)
# Episode 53 finished. Total reward: 29.0 (29 timesteps)
# Episode 54 finished. Total reward: 25.0 (25 timesteps)
# Episode 55 finished. Total reward: 11.0 (11 timesteps)
# Episode 56 finished. Total reward: 12.0 (12 timesteps)
# Episode 57 finished. Total reward: 26.0 (26 timesteps)
# Episode 58 finished. Total reward: 9.0 (9 timesteps)
# Episode 59 finished. Total reward: 10.0 (10 timesteps)
# Episode 60 finished. Total reward: 27.0 (27 timesteps)
# Episode 61 finished. Total reward: 36.0 (36 timesteps)
# Episode 62 finished. Total reward: 17.0 (17 timesteps)
# Episode 63 finished. Total reward: 19.0 (19 timesteps)
# Episode 64 finished. Total reward: 24.0 (24 timesteps)
# Episode 65 finished. Total reward: 16.0 (16 timesteps)
# Episode 66 finished. Total reward: 32.0 (32 timesteps)
# Episode 67 finished. Total reward: 16.0 (16 timesteps)
# Episode 68 finished. Total reward: 16.0 (16 timesteps)
# Episode 69 finished. Total reward: 14.0 (14 timesteps)
# Episode 70 finished. Total reward: 17.0 (17 timesteps)
# Episode 71 finished. Total reward: 13.0 (13 timesteps)
# Episode 72 finished. Total reward: 32.0 (32 timesteps)
# Episode 73 finished. Total reward: 16.0 (16 timesteps)
# Episode 74 finished. Total reward: 18.0 (18 timesteps)
# Episode 75 finished. Total reward: 25.0 (25 timesteps)
# Episode 76 finished. Total reward: 26.0 (26 timesteps)
# Episode 77 finished. Total reward: 21.0 (21 timesteps)
# Episode 78 finished. Total reward: 19.0 (19 timesteps)
# Episode 79 finished. Total reward: 18.0 (18 timesteps)
# Episode 80 finished. Total reward: 11.0 (11 timesteps)
# Episode 81 finished. Total reward: 28.0 (28 timesteps)
# Episode 82 finished. Total reward: 15.0 (15 timesteps)
# Episode 83 finished. Total reward: 38.0 (38 timesteps)
# Episode 84 finished. Total reward: 13.0 (13 timesteps)
# Episode 85 finished. Total reward: 20.0 (20 timesteps)
# Episode 86 finished. Total reward: 26.0 (26 timesteps)
# Episode 87 finished. Total reward: 22.0 (22 timesteps)
# Episode 88 finished. Total reward: 22.0 (22 timesteps)
# Episode 89 finished. Total reward: 16.0 (16 timesteps)
# Episode 90 finished. Total reward: 23.0 (23 timesteps)
# Episode 91 finished. Total reward: 22.0 (22 timesteps)
# Episode 92 finished. Total reward: 15.0 (15 timesteps)
# Episode 93 finished. Total reward: 13.0 (13 timesteps)
# Updating the policy...
# Updating finished!
# Episode 94 finished. Total reward: 28.0 (28 timesteps)
# Episode 95 finished. Total reward: 17.0 (17 timesteps)
# Episode 96 finished. Total reward: 32.0 (32 timesteps)
# Episode 97 finished. Total reward: 19.0 (19 timesteps)
# Episode 98 finished. Total reward: 13.0 (13 timesteps)
# Episode 99 finished. Total reward: 16.0 (16 timesteps)
# Episode 100 finished. Total reward: 25.0 (25 timesteps)
# Episode 101 finished. Total reward: 29.0 (29 timesteps)
# Episode 102 finished. Total reward: 22.0 (22 timesteps)
# Episode 103 finished. Total reward: 12.0 (12 timesteps)
# Episode 104 finished. Total reward: 23.0 (23 timesteps)
# Episode 105 finished. Total reward: 24.0 (24 timesteps)
# Episode 106 finished. Total reward: 50.0 (50 timesteps)
# Episode 107 finished. Total reward: 52.0 (52 timesteps)
# Episode 108 finished. Total reward: 19.0 (19 timesteps)
# Episode 109 finished. Total reward: 12.0 (12 timesteps)
# Episode 110 finished. Total reward: 27.0 (27 timesteps)
# Episode 111 finished. Total reward: 18.0 (18 timesteps)
# Episode 112 finished. Total reward: 28.0 (28 timesteps)
# Episode 113 finished. Total reward: 77.0 (77 timesteps)
# Episode 114 finished. Total reward: 20.0 (20 timesteps)
# Episode 115 finished. Total reward: 32.0 (32 timesteps)
# Episode 116 finished. Total reward: 20.0 (20 timesteps)
# Episode 117 finished. Total reward: 21.0 (21 timesteps)
# Episode 118 finished. Total reward: 14.0 (14 timesteps)
# Episode 119 finished. Total reward: 33.0 (33 timesteps)
# Episode 120 finished. Total reward: 31.0 (31 timesteps)
# Episode 121 finished. Total reward: 19.0 (19 timesteps)
# Episode 122 finished. Total reward: 28.0 (28 timesteps)
# Episode 123 finished. Total reward: 26.0 (26 timesteps)
# Episode 124 finished. Total reward: 82.0 (82 timesteps)
# Episode 125 finished. Total reward: 25.0 (25 timesteps)
# Episode 126 finished. Total reward: 30.0 (30 timesteps)
# Episode 127 finished. Total reward: 19.0 (19 timesteps)
# Episode 128 finished. Total reward: 12.0 (12 timesteps)
# Episode 129 finished. Total reward: 47.0 (47 timesteps)
# Episode 130 finished. Total reward: 39.0 (39 timesteps)
# Episode 131 finished. Total reward: 19.0 (19 timesteps)
# Episode 132 finished. Total reward: 20.0 (20 timesteps)
# Episode 133 finished. Total reward: 37.0 (37 timesteps)
# Episode 134 finished. Total reward: 46.0 (46 timesteps)
# Episode 135 finished. Total reward: 52.0 (52 timesteps)
# Episode 136 finished. Total reward: 12.0 (12 timesteps)
# Episode 137 finished. Total reward: 17.0 (17 timesteps)
# Episode 138 finished. Total reward: 15.0 (15 timesteps)
# Episode 139 finished. Total reward: 25.0 (25 timesteps)
# Episode 140 finished. Total reward: 11.0 (11 timesteps)
# Episode 141 finished. Total reward: 18.0 (18 timesteps)
# Episode 142 finished. Total reward: 10.0 (10 timesteps)
# Episode 143 finished. Total reward: 13.0 (13 timesteps)
# Episode 144 finished. Total reward: 45.0 (45 timesteps)
# Episode 145 finished. Total reward: 41.0 (41 timesteps)
# Episode 146 finished. Total reward: 18.0 (18 timesteps)
# Episode 147 finished. Total reward: 10.0 (10 timesteps)
# Episode 148 finished. Total reward: 16.0 (16 timesteps)
# Episode 149 finished. Total reward: 75.0 (75 timesteps)
# Episode 150 finished. Total reward: 49.0 (49 timesteps)
# Episode 151 finished. Total reward: 39.0 (39 timesteps)
# Episode 152 finished. Total reward: 16.0 (16 timesteps)
# Episode 153 finished. Total reward: 16.0 (16 timesteps)
# Episode 154 finished. Total reward: 19.0 (19 timesteps)
# Episode 155 finished. Total reward: 45.0 (45 timesteps)
# Episode 156 finished. Total reward: 17.0 (17 timesteps)
# Episode 157 finished. Total reward: 19.0 (19 timesteps)
# Episode 158 finished. Total reward: 20.0 (20 timesteps)
# Episode 159 finished. Total reward: 23.0 (23 timesteps)
# Episode 160 finished. Total reward: 32.0 (32 timesteps)
# Episode 161 finished. Total reward: 11.0 (11 timesteps)
# Episode 162 finished. Total reward: 44.0 (44 timesteps)
# Episode 163 finished. Total reward: 14.0 (14 timesteps)
# Episode 164 finished. Total reward: 17.0 (17 timesteps)
# Episode 165 finished. Total reward: 12.0 (12 timesteps)
# Episode 166 finished. Total reward: 15.0 (15 timesteps)
# Episode 167 finished. Total reward: 25.0 (25 timesteps)
# Episode 168 finished. Total reward: 18.0 (18 timesteps)
# Episode 169 finished. Total reward: 22.0 (22 timesteps)
# Updating the policy...
# Updating finished!
# Episode 170 finished. Total reward: 19.0 (19 timesteps)
# Episode 171 finished. Total reward: 25.0 (25 timesteps)
# Episode 172 finished. Total reward: 15.0 (15 timesteps)
# Episode 173 finished. Total reward: 23.0 (23 timesteps)
# Episode 174 finished. Total reward: 80.0 (80 timesteps)
# Episode 175 finished. Total reward: 33.0 (33 timesteps)
# Episode 176 finished. Total reward: 53.0 (53 timesteps)
# Episode 177 finished. Total reward: 16.0 (16 timesteps)
# Episode 178 finished. Total reward: 15.0 (15 timesteps)
# Episode 179 finished. Total reward: 44.0 (44 timesteps)
# Episode 180 finished. Total reward: 56.0 (56 timesteps)
# Episode 181 finished. Total reward: 20.0 (20 timesteps)
# Episode 182 finished. Total reward: 37.0 (37 timesteps)
# Episode 183 finished. Total reward: 51.0 (51 timesteps)
# Episode 184 finished. Total reward: 14.0 (14 timesteps)
# Episode 185 finished. Total reward: 29.0 (29 timesteps)
# Episode 186 finished. Total reward: 28.0 (28 timesteps)
# Episode 187 finished. Total reward: 56.0 (56 timesteps)
# Episode 188 finished. Total reward: 44.0 (44 timesteps)
# Episode 189 finished. Total reward: 17.0 (17 timesteps)
# Episode 190 finished. Total reward: 42.0 (42 timesteps)
# Episode 191 finished. Total reward: 18.0 (18 timesteps)
# Episode 192 finished. Total reward: 52.0 (52 timesteps)
# Episode 193 finished. Total reward: 46.0 (46 timesteps)
# Episode 194 finished. Total reward: 25.0 (25 timesteps)
# Episode 195 finished. Total reward: 11.0 (11 timesteps)
# Episode 196 finished. Total reward: 41.0 (41 timesteps)
# Episode 197 finished. Total reward: 51.0 (51 timesteps)
# Episode 198 finished. Total reward: 16.0 (16 timesteps)
# Episode 199 finished. Total reward: 61.0 (61 timesteps)
# Episode 200 finished. Total reward: 29.0 (29 timesteps)
# Episode 201 finished. Total reward: 44.0 (44 timesteps)
# Episode 202 finished. Total reward: 70.0 (70 timesteps)
# Episode 203 finished. Total reward: 39.0 (39 timesteps)
# Episode 204 finished. Total reward: 42.0 (42 timesteps)
# Episode 205 finished. Total reward: 10.0 (10 timesteps)
# Episode 206 finished. Total reward: 41.0 (41 timesteps)
# Episode 207 finished. Total reward: 34.0 (34 timesteps)
# Episode 208 finished. Total reward: 41.0 (41 timesteps)
# Episode 209 finished. Total reward: 42.0 (42 timesteps)
# Episode 210 finished. Total reward: 45.0 (45 timesteps)
# Episode 211 finished. Total reward: 21.0 (21 timesteps)
# Episode 212 finished. Total reward: 11.0 (11 timesteps)
# Episode 213 finished. Total reward: 14.0 (14 timesteps)
# Episode 214 finished. Total reward: 38.0 (38 timesteps)
# Episode 215 finished. Total reward: 29.0 (29 timesteps)
# Episode 216 finished. Total reward: 47.0 (47 timesteps)
# Episode 217 finished. Total reward: 45.0 (45 timesteps)
# Episode 218 finished. Total reward: 48.0 (48 timesteps)
# Episode 219 finished. Total reward: 80.0 (80 timesteps)
# Episode 220 finished. Total reward: 15.0 (15 timesteps)
# Episode 221 finished. Total reward: 22.0 (22 timesteps)
# Episode 222 finished. Total reward: 87.0 (87 timesteps)
# Episode 223 finished. Total reward: 27.0 (27 timesteps)
# Episode 224 finished. Total reward: 33.0 (33 timesteps)
# Episode 225 finished. Total reward: 16.0 (16 timesteps)
# Updating the policy...
# Updating finished!
# Episode 226 finished. Total reward: 27.0 (27 timesteps)
# Episode 227 finished. Total reward: 100.0 (100 timesteps)
# Episode 228 finished. Total reward: 29.0 (29 timesteps)
# Episode 229 finished. Total reward: 58.0 (58 timesteps)
# Episode 230 finished. Total reward: 100.0 (100 timesteps)
# Episode 231 finished. Total reward: 41.0 (41 timesteps)
# Episode 232 finished. Total reward: 28.0 (28 timesteps)
# Episode 233 finished. Total reward: 100.0 (100 timesteps)
# Episode 234 finished. Total reward: 49.0 (49 timesteps)
# ...
# Episode 243 finished. Total reward: 100.0 (100 timesteps)
# Episode 244 finished. Total reward: 100.0 (100 timesteps)
# Episode 245 finished. Total reward: 100.0 (100 timesteps)
# Episode 246 finished. Total reward: 100.0 (100 timesteps)
# Episode 247 finished. Total reward: 83.0 (83 timesteps)
# Episode 248 finished. Total reward: 99.0 (99 timesteps)
# Episode 249 finished. Total reward: 100.0 (100 timesteps)
# Episode 250 finished. Total reward: 36.0 (36 timesteps)
# Episode 251 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 252 finished. Total reward: 100.0 (100 timesteps)
# Episode 253 finished. Total reward: 92.0 (92 timesteps)
# Episode 254 finished. Total reward: 80.0 (80 timesteps)
# Episode 255 finished. Total reward: 100.0 (100 timesteps)
# Episode 256 finished. Total reward: 100.0 (100 timesteps)
# Episode 257 finished. Total reward: 100.0 (100 timesteps)
# Episode 258 finished. Total reward: 100.0 (100 timesteps)
# Episode 259 finished. Total reward: 80.0 (80 timesteps)
# Episode 260 finished. Total reward: 100.0 (100 timesteps)
# Episode 261 finished. Total reward: 100.0 (100 timesteps)
# Episode 262 finished. Total reward: 100.0 (100 timesteps)
# Episode 263 finished. Total reward: 100.0 (100 timesteps)
# Episode 264 finished. Total reward: 100.0 (100 timesteps)
# Episode 265 finished. Total reward: 63.0 (63 timesteps)
# Episode 266 finished. Total reward: 100.0 (100 timesteps)
# Episode 267 finished. Total reward: 100.0 (100 timesteps)
# Episode 268 finished. Total reward: 100.0 (100 timesteps)
# Episode 269 finished. Total reward: 100.0 (100 timesteps)
# Episode 270 finished. Total reward: 100.0 (100 timesteps)
# Episode 271 finished. Total reward: 100.0 (100 timesteps)
# Episode 272 finished. Total reward: 77.0 (77 timesteps)
# Updating the policy...
# Updating finished!
# Episode 273 finished. Total reward: 100.0 (100 timesteps)
# Episode 274 finished. Total reward: 100.0 (100 timesteps)
# Episode 275 finished. Total reward: 100.0 (100 timesteps)
# Episode 276 finished. Total reward: 100.0 (100 timesteps)
# Episode 277 finished. Total reward: 100.0 (100 timesteps)
# Episode 278 finished. Total reward: 100.0 (100 timesteps)
# Episode 279 finished. Total reward: 100.0 (100 timesteps)
# Episode 280 finished. Total reward: 100.0 (100 timesteps)
# Episode 281 finished. Total reward: 100.0 (100 timesteps)
# Episode 282 finished. Total reward: 38.0 (38 timesteps)
# Episode 283 finished. Total reward: 100.0 (100 timesteps)
# Episode 284 finished. Total reward: 100.0 (100 timesteps)
# Episode 285 finished. Total reward: 100.0 (100 timesteps)
# Episode 286 finished. Total reward: 100.0 (100 timesteps)
# Episode 287 finished. Total reward: 100.0 (100 timesteps)
# Episode 288 finished. Total reward: 100.0 (100 timesteps)
# Episode 289 finished. Total reward: 100.0 (100 timesteps)
# Episode 290 finished. Total reward: 100.0 (100 timesteps)
# Episode 291 finished. Total reward: 100.0 (100 timesteps)
# Episode 292 finished. Total reward: 100.0 (100 timesteps)
# Episode 293 finished. Total reward: 30.0 (30 timesteps)
# Episode 294 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 295 finished. Total reward: 100.0 (100 timesteps)
# Episode 296 finished. Total reward: 100.0 (100 timesteps)
# Episode 297 finished. Total reward: 100.0 (100 timesteps)
# Episode 298 finished. Total reward: 100.0 (100 timesteps)
# Episode 299 finished. Total reward: 100.0 (100 timesteps)
# Episode 300 finished. Total reward: 100.0 (100 timesteps)
# Episode 301 finished. Total reward: 100.0 (100 timesteps)
# Episode 302 finished. Total reward: 100.0 (100 timesteps)
# Episode 303 finished. Total reward: 100.0 (100 timesteps)
# Episode 304 finished. Total reward: 100.0 (100 timesteps)
# Episode 305 finished. Total reward: 100.0 (100 timesteps)
# Episode 306 finished. Total reward: 100.0 (100 timesteps)
# Episode 307 finished. Total reward: 100.0 (100 timesteps)
# Episode 308 finished. Total reward: 100.0 (100 timesteps)
# Episode 309 finished. Total reward: 100.0 (100 timesteps)
# Episode 310 finished. Total reward: 100.0 (100 timesteps)
# Episode 311 finished. Total reward: 100.0 (100 timesteps)
# Episode 312 finished. Total reward: 98.0 (98 timesteps)
# Episode 313 finished. Total reward: 100.0 (100 timesteps)
# Episode 314 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 315 finished. Total reward: 100.0 (100 timesteps)
# Episode 316 finished. Total reward: 100.0 (100 timesteps)
# Episode 317 finished. Total reward: 100.0 (100 timesteps)
# Episode 318 finished. Total reward: 100.0 (100 timesteps)
# Episode 319 finished. Total reward: 100.0 (100 timesteps)
# Episode 320 finished. Total reward: 100.0 (100 timesteps)
# Episode 321 finished. Total reward: 100.0 (100 timesteps)
# Episode 322 finished. Total reward: 100.0 (100 timesteps)
# Episode 323 finished. Total reward: 100.0 (100 timesteps)
# Episode 324 finished. Total reward: 100.0 (100 timesteps)
# Episode 325 finished. Total reward: 100.0 (100 timesteps)
# Episode 326 finished. Total reward: 100.0 (100 timesteps)
# Episode 327 finished. Total reward: 100.0 (100 timesteps)
# Episode 328 finished. Total reward: 100.0 (100 timesteps)
# Episode 329 finished. Total reward: 100.0 (100 timesteps)
# Episode 330 finished. Total reward: 100.0 (100 timesteps)
# Episode 331 finished. Total reward: 100.0 (100 timesteps)
# Episode 332 finished. Total reward: 100.0 (100 timesteps)
# Episode 333 finished. Total reward: 100.0 (100 timesteps)
# Episode 334 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 335 finished. Total reward: 60.0 (60 timesteps)
# Episode 336 finished. Total reward: 67.0 (67 timesteps)
# Episode 337 finished. Total reward: 65.0 (65 timesteps)
# Episode 338 finished. Total reward: 100.0 (100 timesteps)
# Episode 339 finished. Total reward: 94.0 (94 timesteps)
# Episode 340 finished. Total reward: 86.0 (86 timesteps)
# Episode 341 finished. Total reward: 97.0 (97 timesteps)
# Episode 342 finished. Total reward: 100.0 (100 timesteps)
# Episode 343 finished. Total reward: 100.0 (100 timesteps)
# Episode 344 finished. Total reward: 74.0 (74 timesteps)
# Episode 345 finished. Total reward: 91.0 (91 timesteps)
# Episode 346 finished. Total reward: 100.0 (100 timesteps)
# Episode 347 finished. Total reward: 100.0 (100 timesteps)
# Episode 348 finished. Total reward: 100.0 (100 timesteps)
# Episode 349 finished. Total reward: 98.0 (98 timesteps)
# Episode 350 finished. Total reward: 67.0 (67 timesteps)
# Episode 351 finished. Total reward: 100.0 (100 timesteps)
# Episode 352 finished. Total reward: 75.0 (75 timesteps)
# Episode 353 finished. Total reward: 93.0 (93 timesteps)
# Episode 354 finished. Total reward: 100.0 (100 timesteps)
# Episode 355 finished. Total reward: 100.0 (100 timesteps)
# Episode 356 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 357 finished. Total reward: 100.0 (100 timesteps)
# Episode 358 finished. Total reward: 100.0 (100 timesteps)
# Episode 359 finished. Total reward: 100.0 (100 timesteps)
# Episode 360 finished. Total reward: 100.0 (100 timesteps)
# Episode 361 finished. Total reward: 100.0 (100 timesteps)
# Episode 362 finished. Total reward: 100.0 (100 timesteps)
# Episode 363 finished. Total reward: 96.0 (96 timesteps)
# Episode 364 finished. Total reward: 100.0 (100 timesteps)
# Episode 365 finished. Total reward: 100.0 (100 timesteps)
# Episode 366 finished. Total reward: 100.0 (100 timesteps)
# Episode 367 finished. Total reward: 100.0 (100 timesteps)
# Episode 368 finished. Total reward: 100.0 (100 timesteps)
# Episode 369 finished. Total reward: 100.0 (100 timesteps)
# Episode 370 finished. Total reward: 100.0 (100 timesteps)
# Episode 371 finished. Total reward: 100.0 (100 timesteps)
# Episode 372 finished. Total reward: 100.0 (100 timesteps)
# Episode 373 finished. Total reward: 100.0 (100 timesteps)
# Episode 374 finished. Total reward: 100.0 (100 timesteps)
# Episode 375 finished. Total reward: 100.0 (100 timesteps)
# Episode 376 finished. Total reward: 58.0 (58 timesteps)
# Episode 377 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 378 finished. Total reward: 100.0 (100 timesteps)
# Episode 379 finished. Total reward: 100.0 (100 timesteps)
# Episode 380 finished. Total reward: 100.0 (100 timesteps)
# Episode 381 finished. Total reward: 76.0 (76 timesteps)
# Episode 382 finished. Total reward: 100.0 (100 timesteps)
# Episode 383 finished. Total reward: 100.0 (100 timesteps)
# Episode 384 finished. Total reward: 100.0 (100 timesteps)
# Episode 385 finished. Total reward: 100.0 (100 timesteps)
# Episode 386 finished. Total reward: 100.0 (100 timesteps)
# Episode 387 finished. Total reward: 97.0 (97 timesteps)
# Episode 388 finished. Total reward: 100.0 (100 timesteps)
# Episode 389 finished. Total reward: 100.0 (100 timesteps)
# Episode 390 finished. Total reward: 75.0 (75 timesteps)
# Episode 391 finished. Total reward: 100.0 (100 timesteps)
# Episode 392 finished. Total reward: 100.0 (100 timesteps)
# Episode 393 finished. Total reward: 100.0 (100 timesteps)
# Episode 394 finished. Total reward: 100.0 (100 timesteps)
# Episode 395 finished. Total reward: 100.0 (100 timesteps)
# Episode 396 finished. Total reward: 100.0 (100 timesteps)
# Episode 397 finished. Total reward: 84.0 (84 timesteps)
# Updating the policy...
# Updating finished!
# Episode 398 finished. Total reward: 100.0 (100 timesteps)
# Episode 399 finished. Total reward: 100.0 (100 timesteps)
# Episode 400 finished. Total reward: 100.0 (100 timesteps)
# Episode 401 finished. Total reward: 100.0 (100 timesteps)
# Episode 402 finished. Total reward: 100.0 (100 timesteps)
# Episode 403 finished. Total reward: 100.0 (100 timesteps)
# Episode 404 finished. Total reward: 100.0 (100 timesteps)
# Episode 405 finished. Total reward: 100.0 (100 timesteps)
# Episode 406 finished. Total reward: 100.0 (100 timesteps)
# Episode 407 finished. Total reward: 100.0 (100 timesteps)
# Episode 408 finished. Total reward: 100.0 (100 timesteps)
# Episode 409 finished. Total reward: 100.0 (100 timesteps)
# Episode 410 finished. Total reward: 37.0 (37 timesteps)
# Episode 411 finished. Total reward: 100.0 (100 timesteps)
# Episode 412 finished. Total reward: 100.0 (100 timesteps)
# Episode 413 finished. Total reward: 100.0 (100 timesteps)
# Episode 414 finished. Total reward: 100.0 (100 timesteps)
# Episode 415 finished. Total reward: 100.0 (100 timesteps)
# Episode 416 finished. Total reward: 100.0 (100 timesteps)
# Episode 417 finished. Total reward: 100.0 (100 timesteps)
# Episode 418 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 419 finished. Total reward: 100.0 (100 timesteps)
# Episode 420 finished. Total reward: 100.0 (100 timesteps)
# Episode 421 finished. Total reward: 100.0 (100 timesteps)
# Episode 422 finished. Total reward: 100.0 (100 timesteps)
# Episode 423 finished. Total reward: 100.0 (100 timesteps)
# Episode 424 finished. Total reward: 51.0 (51 timesteps)
# Episode 425 finished. Total reward: 82.0 (82 timesteps)
# Episode 426 finished. Total reward: 100.0 (100 timesteps)
# Episode 427 finished. Total reward: 97.0 (97 timesteps)
# Episode 428 finished. Total reward: 50.0 (50 timesteps)
# Episode 429 finished. Total reward: 100.0 (100 timesteps)
# Episode 430 finished. Total reward: 100.0 (100 timesteps)
# Episode 431 finished. Total reward: 14.0 (14 timesteps)
# Episode 432 finished. Total reward: 100.0 (100 timesteps)
# Episode 433 finished. Total reward: 100.0 (100 timesteps)
# Episode 434 finished. Total reward: 100.0 (100 timesteps)
# Episode 435 finished. Total reward: 100.0 (100 timesteps)
# Episode 436 finished. Total reward: 100.0 (100 timesteps)
# Episode 437 finished. Total reward: 100.0 (100 timesteps)
# Episode 438 finished. Total reward: 100.0 (100 timesteps)
# Episode 439 finished. Total reward: 100.0 (100 timesteps)
# Episode 440 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 441 finished. Total reward: 100.0 (100 timesteps)
# Episode 442 finished. Total reward: 100.0 (100 timesteps)
# Episode 443 finished. Total reward: 100.0 (100 timesteps)
# Episode 444 finished. Total reward: 100.0 (100 timesteps)
# Episode 445 finished. Total reward: 100.0 (100 timesteps)
# Episode 446 finished. Total reward: 100.0 (100 timesteps)
# Episode 447 finished. Total reward: 100.0 (100 timesteps)
# Episode 448 finished. Total reward: 100.0 (100 timesteps)
# Episode 449 finished. Total reward: 100.0 (100 timesteps)
# Episode 450 finished. Total reward: 100.0 (100 timesteps)
# Episode 451 finished. Total reward: 100.0 (100 timesteps)
# Episode 452 finished. Total reward: 100.0 (100 timesteps)
# Episode 453 finished. Total reward: 100.0 (100 timesteps)
# Episode 454 finished. Total reward: 100.0 (100 timesteps)
# Episode 455 finished. Total reward: 100.0 (100 timesteps)
# Episode 456 finished. Total reward: 100.0 (100 timesteps)
# Episode 457 finished. Total reward: 100.0 (100 timesteps)
# Episode 458 finished. Total reward: 100.0 (100 timesteps)
# Episode 459 finished. Total reward: 100.0 (100 timesteps)
# Episode 460 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 461 finished. Total reward: 100.0 (100 timesteps)
# Episode 462 finished. Total reward: 100.0 (100 timesteps)
# Episode 463 finished. Total reward: 13.0 (13 timesteps)
# Episode 464 finished. Total reward: 100.0 (100 timesteps)
# Episode 465 finished. Total reward: 100.0 (100 timesteps)
# Episode 466 finished. Total reward: 100.0 (100 timesteps)
# Episode 467 finished. Total reward: 100.0 (100 timesteps)
# Episode 468 finished. Total reward: 100.0 (100 timesteps)
# Episode 469 finished. Total reward: 100.0 (100 timesteps)
# Episode 470 finished. Total reward: 100.0 (100 timesteps)
# Episode 471 finished. Total reward: 100.0 (100 timesteps)
# Episode 472 finished. Total reward: 30.0 (30 timesteps)
# Episode 473 finished. Total reward: 100.0 (100 timesteps)
# Episode 474 finished. Total reward: 100.0 (100 timesteps)
# Episode 475 finished. Total reward: 100.0 (100 timesteps)
# Episode 476 finished. Total reward: 100.0 (100 timesteps)
# Episode 477 finished. Total reward: 100.0 (100 timesteps)
# Episode 478 finished. Total reward: 100.0 (100 timesteps)
# Episode 479 finished. Total reward: 100.0 (100 timesteps)
# Episode 480 finished. Total reward: 100.0 (100 timesteps)
# Episode 481 finished. Total reward: 100.0 (100 timesteps)
# Episode 482 finished. Total reward: 100.0 (100 timesteps)
# Updating the policy...
# Updating finished!
# Episode 483 finished. Total reward: 100.0 (100 timesteps)
# Episode 484 finished. Total reward: 100.0 (100 timesteps)
# Episode 485 finished. Total reward: 100.0 (100 timesteps)
# Episode 486 finished. Total reward: 100.0 (100 timesteps)
# Episode 487 finished. Total reward: 100.0 (100 timesteps)
# Episode 488 finished. Total reward: 100.0 (100 timesteps)
# Episode 489 finished. Total reward: 100.0 (100 timesteps)
# Episode 490 finished. Total reward: 100.0 (100 timesteps)
# Episode 491 finished. Total reward: 100.0 (100 timesteps)
# Episode 492 finished. Total reward: 100.0 (100 timesteps)
# Episode 493 finished. Total reward: 100.0 (100 timesteps)
# Episode 494 finished. Total reward: 100.0 (100 timesteps)
# Episode 495 finished. Total reward: 100.0 (100 timesteps)
# Episode 496 finished. Total reward: 100.0 (100 timesteps)
# Episode 497 finished. Total reward: 100.0 (100 timesteps)
# Episode 498 finished. Total reward: 100.0 (100 timesteps)
# Episode 499 finished. Total reward: 100.0 (100 timesteps)
# Episode 500 finished. Total reward: 100.0 (100 timesteps)
# Model saved to /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt
# ------Training finished.------
# Numpy/Torch/Random Seed:  85
# Loading model from /notebooks/rl2023/ex1/results/model/CartPole-v1_params.pt ...
# Testing...
# Test ep reward: 150.0 seed: 85
# Test ep reward: 150.0 seed: 85
# Test ep reward: 150.0 seed: 85
# Test ep reward: 150.0 seed: 85
# Test ep reward: 150.0 seed: 85
# Test ep reward: 150.0 seed: 85
# Test ep reward: 150.0 seed: 85
# Test ep reward: 150.0 seed: 85
# Test ep reward: 150.0 seed: 85
# Test ep reward: 150.0 seed: 85
# Average test reward: 150.0 episode length: 150.0

# %% [markdown]
# <a id='Q2'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 2.1</b> Analysis of Training Performance (15 points) </h3>
#
# Are the behavior and performance of the trained models the same every time? Why/why not? Analyze the causes briefly.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# No, they're not same. I think it based on the different situation such like random seeds, stochasticity of the environment and so on.  random seeds can lead to different training trajectories and model parameter initializations. Stochasticity of the environment means even the same envionment the response will differernt. They both affect the model's behavior and performance.

# %% [markdown]
# <a id='Q3'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 2.2</b> Stochasticity (10 points) </h3>
#
# What are the implications of this stochasticity, when it comes to comparing reinforcement learning algorithms to each other? Please explain.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# In a single run, it is challenging to ascertain the efficiency of different algorithms. Multiple runs, on the other hand, offer a more robust reflection of algorithm performance and help mitigate the impact of random fluctuations. When differences between algorithms observed in a single run are consistently reflected in the results of multiple runs, it underscores inherent performance disparities among the algorithms. This aligns better with the requirements of real-world uncertainty and allows for consideration of more uncertain scenarios.
#
# Furthermore, in adapting to diverse tasks, parameter tuning may also involve an element of randomness, and this stochasticity can facilitate the optimization process.

# %% [markdown]
# # Reacher <a id='3.'></a>
#
# Now we will focus on designing a reward function for a different environment, the Reacher environment, where a two-joint manipulator needs to reach a goal (see Figure 2).
#
# <figure>
# <img src="imgs/reacher.png" width="200px">
# <figcaption style="text-align: center"> Figure 2: The Reacher environment  </figcaption>
# </figure>
#
# The Cartesian ($x$, $y$) position of the end-effector of the manipulator can be determined following the equation:
#
# $$
#  x = L_1 \sin(\theta_0)+L_2 \sin(\theta_0+\theta_1)\\
#  y = -L_1 \cos(\theta_0)-L_2 \cos(\theta_0+\theta_1)
# $$
#
# where $L1 = 1$, $L2 = 1$ are the lengths, and $\theta_0$, $\theta_1$ the joint angles of the first and second links respectively. The state (and observation) in this environment is the two element vector:
#
# $$
# o=s=\left(\begin{array}{c}
# \theta_0 \\
# \theta_1 \\
# \end{array}\right) \text {, }
# $$
#
# The action space now consists of 5 "options"; 4 correspond rotating the first/second joint left/right, and the final one performs no motion at all (the configuration doesn’t change). The episode terminates when the agent reaches the target position, marked in red. Now, let us design a custom reward function and use it for training the RL agent.

# %% [markdown]
# <a id='T3'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 3.</b> Reward Functions (20 points) </h3>
#
# Below two classes are shown that modify the reward function of the reacher function provided in ```reacher.py```. Edit the function ```get_reward``` _below_ (not in ```reacher.py```) in both classes. For each class, write a reward function to incentivise the agent to learn the following behaviors:
#
# Class 1) ```SpinningReacherEnv```: Keep the manipulator rotating clockwise continuously (w.r.t. angle θ_0). You can use a lower number of training episodes for this, e.g. train(cfg_args=dict(env_name='SpinningReacher-v0', train_episodes=200), overrides=['env=reacher_v1'])
#
# Class 2) ```TargetReacherEnv```: Reach the goal point located in x = [1.0,1.0] (marked in red). Use at least 500 training episodes.
#
# Train one model for each behavior.
#
# **Hint:** Use the observation vector to get the quantities required to compute the new reward (such as the position of the manipulator). You can get the Cartesian position of the end-effector with ```self.get_cartesian_pos(state)```.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
from reacher import ReacherEnv
from typing import Optional
from gymnasium.envs.registration import register

class SpinningReacherEnv(ReacherEnv):
    def __init__(self, render_mode: Optional[str] = None, max_episode_steps=200):
        super().__init__(render_mode=render_mode, max_episode_steps=max_episode_steps)
        
    def get_reward(self, prev_state, action, next_state):
        # TODO: Task 3: Implement and test the first reward function
        ########## Your code starts here ##########
        current_theta = prev_state[0]
        next_theta = next_state[0]
        
        delta_theta = next_theta - current_theta
        
        if delta_theta < 0:
            reward = 1
        else:
            reward = -1
        return reward
        ########## Your codes end here ########## 
        
    
register("SpinningReacher-v0",
        entry_point="%s:SpinningReacherEnv"%__name__,
        max_episode_steps=200)

import numpy as np

class TargetReacherEnv(ReacherEnv):
    def __init__(self, render_mode: Optional[str] = None, max_episode_steps=200):
        super().__init__(render_mode=render_mode, max_episode_steps=max_episode_steps)
        
    def get_reward(self, prev_state, action, next_state):
        # Calculate distances
        goal_point = [1.0,1.0]
        prev_point = self.get_cartesian_pos(prev_state)
        prev_distance = np.sqrt(np.sum((prev_point - goal_point)**2))
     
        # # Calculate reward
        # if prev_distance < 0.1:
        #     reward = 10
        # else:
        #     reward = -0.1
        reward = - prev_distance
        return reward
        
register("TargetReacher-v0",
        entry_point="%s:TargetReacherEnv"%__name__,
        max_episode_steps=500)
# Out:
# /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment SpinningReacher-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment TargetReacher-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
t.train(cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
      cfg_args=dict(env_name='SpinningReacher-v0', train_episodes=200)) # < 5 mins
# Out:
# Numpy/Torch/Random Seed:  99
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/notebooks/rl2023/ex1/wandb/run-20230918_150653-kjj4t623</code>
# Syncing run <strong><a href='https://wandb.ai/mayangle/rl_aalto/runs/kjj4t623' target="_blank">ex1-SpinningReacher-v0-None-1695038813</a></strong> to <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">https://wandb.ai/mayangle/rl_aalto</a>
#  View run at <a href='https://wandb.ai/mayangle/rl_aalto/runs/kjj4t623' target="_blank">https://wandb.ai/mayangle/rl_aalto/runs/kjj4t623</a>
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/SpinningReacher-v0/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Configuration Settings: {'exp_name': 'ex1', 'seed': None, 'env_name': 'SpinningReacher-v0', 'max_episode_steps': 200, 'train_episodes': 200, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 2
# Action space dimensions: 5
#
# Episode 0 finished. Total reward: -116 (200 timesteps)
# Episode 1 finished. Total reward: -108 (200 timesteps)
# Episode 2 finished. Total reward: -114 (200 timesteps)
# Episode 3 finished. Total reward: -140 (200 timesteps)
# Episode 4 finished. Total reward: -124 (200 timesteps)
# Episode 5 finished. Total reward: -134 (200 timesteps)
# Episode 6 finished. Total reward: -114 (200 timesteps)
# Episode 7 finished. Total reward: -37 (95 timesteps)
# Episode 8 finished. Total reward: -116 (200 timesteps)
# Episode 9 finished. Total reward: -122 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 10 finished. Total reward: -102 (200 timesteps)
# Episode 11 finished. Total reward: -102 (200 timesteps)
# Episode 12 finished. Total reward: -98 (196 timesteps)
# Episode 13 finished. Total reward: -98 (200 timesteps)
# Episode 14 finished. Total reward: -86 (200 timesteps)
# Episode 15 finished. Total reward: -98 (200 timesteps)
# Episode 16 finished. Total reward: -53 (121 timesteps)
# Episode 17 finished. Total reward: -32 (76 timesteps)
# Episode 18 finished. Total reward: -110 (200 timesteps)
# Episode 19 finished. Total reward: -128 (200 timesteps)
# Episode 20 finished. Total reward: -100 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 21 finished. Total reward: -82 (200 timesteps)
# Episode 22 finished. Total reward: -41 (113 timesteps)
# Episode 23 finished. Total reward: -78 (200 timesteps)
# Episode 24 finished. Total reward: -68 (200 timesteps)
# Episode 25 finished. Total reward: -33 (87 timesteps)
# Episode 26 finished. Total reward: -54 (200 timesteps)
# Episode 27 finished. Total reward: -90 (184 timesteps)
# Episode 28 finished. Total reward: -53 (137 timesteps)
# Episode 29 finished. Total reward: -44 (110 timesteps)
# Episode 30 finished. Total reward: -41 (115 timesteps)
# Episode 31 finished. Total reward: -10 (50 timesteps)
# Episode 32 finished. Total reward: -72 (200 timesteps)
# Episode 33 finished. Total reward: -82 (200 timesteps)
# Episode 34 finished. Total reward: -44 (94 timesteps)
# Updating the policy...
# Updating finished!
# Episode 35 finished. Total reward: -34 (88 timesteps)
# Episode 36 finished. Total reward: -34 (200 timesteps)
# Episode 37 finished. Total reward: -42 (200 timesteps)
# Episode 38 finished. Total reward: -5 (49 timesteps)
# Episode 39 finished. Total reward: -12 (62 timesteps)
# Episode 40 finished. Total reward: -49 (191 timesteps)
# Episode 41 finished. Total reward: -64 (200 timesteps)
# Episode 42 finished. Total reward: -64 (200 timesteps)
# Episode 43 finished. Total reward: -9 (53 timesteps)
# Episode 44 finished. Total reward: -59 (179 timesteps)
# Episode 45 finished. Total reward: -26 (174 timesteps)
# Episode 46 finished. Total reward: -16 (68 timesteps)
# Episode 47 finished. Total reward: -31 (177 timesteps)
# Updating the policy...
# Updating finished!
# Episode 48 finished. Total reward: -62 (200 timesteps)
# Episode 49 finished. Total reward: 19 (175 timesteps)
# Episode 50 finished. Total reward: 0 (120 timesteps)
# Episode 51 finished. Total reward: -26 (200 timesteps)
# Episode 52 finished. Total reward: 25 (163 timesteps)
# Episode 53 finished. Total reward: -17 (67 timesteps)
# Episode 54 finished. Total reward: 2 (34 timesteps)
# Episode 55 finished. Total reward: -30 (200 timesteps)
# Episode 56 finished. Total reward: -3 (117 timesteps)
# Episode 57 finished. Total reward: -11 (139 timesteps)
# Episode 58 finished. Total reward: -6 (48 timesteps)
# Episode 59 finished. Total reward: -37 (177 timesteps)
# Episode 60 finished. Total reward: -8 (200 timesteps)
# Episode 61 finished. Total reward: -44 (200 timesteps)
# Episode 62 finished. Total reward: 7 (101 timesteps)
# Episode 63 finished. Total reward: 2 (32 timesteps)
# Updating the policy...
# Updating finished!
# Episode 64 finished. Total reward: 61 (189 timesteps)
# Episode 65 finished. Total reward: 22 (82 timesteps)
# Episode 66 finished. Total reward: 26 (72 timesteps)
# Episode 67 finished. Total reward: 28 (86 timesteps)
# Episode 68 finished. Total reward: 21 (89 timesteps)
# Episode 69 finished. Total reward: 38 (128 timesteps)
# Episode 70 finished. Total reward: 8 (36 timesteps)
# Episode 71 finished. Total reward: 68 (200 timesteps)
# Episode 72 finished. Total reward: 5 (109 timesteps)
# Episode 73 finished. Total reward: 60 (200 timesteps)
# Episode 74 finished. Total reward: 82 (200 timesteps)
# Episode 75 finished. Total reward: 28 (200 timesteps)
# Episode 76 finished. Total reward: 120 (200 timesteps)
# Episode 77 finished. Total reward: 3 (33 timesteps)
# Updating the policy...
# Updating finished!
# Episode 78 finished. Total reward: 50 (200 timesteps)
# Episode 79 finished. Total reward: 74 (160 timesteps)
# Episode 80 finished. Total reward: 166 (200 timesteps)
# Episode 81 finished. Total reward: 71 (163 timesteps)
# Episode 82 finished. Total reward: 36 (200 timesteps)
# Episode 83 finished. Total reward: 87 (153 timesteps)
# Episode 84 finished. Total reward: 24 (74 timesteps)
# Episode 85 finished. Total reward: 82 (200 timesteps)
# Episode 86 finished. Total reward: 100 (200 timesteps)
# Episode 87 finished. Total reward: 120 (200 timesteps)
# Episode 88 finished. Total reward: 104 (188 timesteps)
# Episode 89 finished. Total reward: 60 (102 timesteps)
# Episode 90 finished. Total reward: 65 (105 timesteps)
# Updating the policy...
# Updating finished!
# Episode 91 finished. Total reward: 158 (200 timesteps)
# Episode 92 finished. Total reward: 117 (169 timesteps)
# Episode 93 finished. Total reward: 153 (199 timesteps)
# Episode 94 finished. Total reward: 67 (95 timesteps)
# Episode 95 finished. Total reward: 122 (170 timesteps)
# Episode 96 finished. Total reward: 153 (195 timesteps)
# Episode 97 finished. Total reward: 128 (200 timesteps)
# Episode 98 finished. Total reward: 94 (130 timesteps)
# Episode 99 finished. Total reward: 174 (200 timesteps)
# Episode 100 finished. Total reward: 122 (200 timesteps)
# Episode 101 finished. Total reward: 170 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 102 finished. Total reward: 144 (200 timesteps)
# Episode 103 finished. Total reward: 162 (200 timesteps)
# Episode 104 finished. Total reward: 182 (200 timesteps)
# Episode 105 finished. Total reward: 170 (200 timesteps)
# Episode 106 finished. Total reward: 162 (200 timesteps)
# Episode 107 finished. Total reward: 160 (200 timesteps)
# Episode 108 finished. Total reward: 164 (200 timesteps)
# Episode 109 finished. Total reward: 170 (200 timesteps)
# Episode 110 finished. Total reward: 160 (200 timesteps)
# Episode 111 finished. Total reward: 158 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 112 finished. Total reward: 180 (200 timesteps)
# Episode 113 finished. Total reward: 174 (200 timesteps)
# Episode 114 finished. Total reward: 172 (200 timesteps)
# Episode 115 finished. Total reward: 174 (200 timesteps)
# Episode 116 finished. Total reward: 178 (200 timesteps)
# Episode 117 finished. Total reward: 158 (200 timesteps)
# Episode 118 finished. Total reward: 172 (200 timesteps)
# Episode 119 finished. Total reward: 174 (200 timesteps)
# Episode 120 finished. Total reward: 170 (200 timesteps)
# Episode 121 finished. Total reward: 180 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 122 finished. Total reward: 168 (200 timesteps)
# Episode 123 finished. Total reward: 182 (200 timesteps)
# Episode 124 finished. Total reward: 176 (200 timesteps)
# Episode 125 finished. Total reward: 168 (192 timesteps)
# Episode 126 finished. Total reward: 178 (200 timesteps)
# Episode 127 finished. Total reward: 178 (200 timesteps)
# Episode 128 finished. Total reward: 171 (189 timesteps)
# Episode 129 finished. Total reward: 176 (200 timesteps)
# Episode 130 finished. Total reward: 186 (200 timesteps)
# Episode 131 finished. Total reward: 180 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 132 finished. Total reward: 182 (200 timesteps)
# Episode 133 finished. Total reward: 186 (200 timesteps)
# Episode 134 finished. Total reward: 186 (200 timesteps)
# Episode 135 finished. Total reward: 186 (200 timesteps)
# Episode 136 finished. Total reward: 192 (200 timesteps)
# Episode 137 finished. Total reward: 176 (200 timesteps)
# Episode 138 finished. Total reward: 188 (200 timesteps)
# Episode 139 finished. Total reward: 184 (200 timesteps)
# Episode 140 finished. Total reward: 188 (200 timesteps)
# Episode 141 finished. Total reward: 190 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 142 finished. Total reward: 182 (200 timesteps)
# Episode 143 finished. Total reward: 194 (200 timesteps)
# Episode 144 finished. Total reward: 190 (200 timesteps)
# Episode 145 finished. Total reward: 194 (200 timesteps)
# Episode 146 finished. Total reward: 182 (200 timesteps)
# Episode 147 finished. Total reward: 186 (200 timesteps)
# Episode 148 finished. Total reward: 198 (200 timesteps)
# Episode 149 finished. Total reward: 194 (200 timesteps)
# Episode 150 finished. Total reward: 194 (200 timesteps)
# Episode 151 finished. Total reward: 190 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 152 finished. Total reward: 194 (200 timesteps)
# Episode 153 finished. Total reward: 196 (200 timesteps)
# Episode 154 finished. Total reward: 196 (200 timesteps)
# Episode 155 finished. Total reward: 198 (200 timesteps)
# Episode 156 finished. Total reward: 194 (200 timesteps)
# Episode 157 finished. Total reward: 192 (200 timesteps)
# Episode 158 finished. Total reward: 200 (200 timesteps)
# Episode 159 finished. Total reward: 194 (200 timesteps)
# Episode 160 finished. Total reward: 196 (200 timesteps)
# Episode 161 finished. Total reward: 192 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 162 finished. Total reward: 194 (200 timesteps)
# Episode 163 finished. Total reward: 198 (200 timesteps)
# Episode 164 finished. Total reward: 198 (200 timesteps)
# Episode 165 finished. Total reward: 200 (200 timesteps)
# Episode 166 finished. Total reward: 200 (200 timesteps)
# Episode 167 finished. Total reward: 196 (200 timesteps)
# Episode 168 finished. Total reward: 198 (200 timesteps)
# Episode 169 finished. Total reward: 196 (200 timesteps)
# Episode 170 finished. Total reward: 200 (200 timesteps)
# Episode 171 finished. Total reward: 198 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 172 finished. Total reward: 200 (200 timesteps)
# Episode 173 finished. Total reward: 200 (200 timesteps)
# Episode 174 finished. Total reward: 198 (200 timesteps)
# Episode 175 finished. Total reward: 200 (200 timesteps)
# Episode 176 finished. Total reward: 200 (200 timesteps)
# Episode 177 finished. Total reward: 198 (200 timesteps)
# Episode 178 finished. Total reward: 198 (200 timesteps)
# Episode 179 finished. Total reward: 200 (200 timesteps)
# Episode 180 finished. Total reward: 200 (200 timesteps)
# Episode 181 finished. Total reward: 198 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 182 finished. Total reward: 194 (200 timesteps)
# Episode 183 finished. Total reward: 198 (200 timesteps)
# Episode 184 finished. Total reward: 192 (200 timesteps)
# Episode 185 finished. Total reward: 196 (200 timesteps)
# Episode 186 finished. Total reward: 194 (200 timesteps)
# Episode 187 finished. Total reward: 196 (200 timesteps)
# Episode 188 finished. Total reward: 194 (200 timesteps)
# Episode 189 finished. Total reward: 196 (200 timesteps)
# Episode 190 finished. Total reward: 198 (200 timesteps)
# Episode 191 finished. Total reward: 198 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 192 finished. Total reward: 198 (200 timesteps)
# Episode 193 finished. Total reward: 200 (200 timesteps)
# Episode 194 finished. Total reward: 196 (200 timesteps)
# Episode 195 finished. Total reward: 196 (200 timesteps)
# Episode 196 finished. Total reward: 200 (200 timesteps)
# Episode 197 finished. Total reward: 200 (200 timesteps)
# Episode 198 finished. Total reward: 200 (200 timesteps)
# Episode 199 finished. Total reward: 200 (200 timesteps)
# Episode 200 finished. Total reward: 200 (200 timesteps)
# Model saved to /notebooks/rl2023/ex1/results/model/SpinningReacher-v0_params.pt
# ------Training finished.------

# %%
t.test(episodes=10, cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
       cfg_args=dict(env_name='SpinningReacher-v0', testing=True, use_wandb=False))
# Out:
# Numpy/Torch/Random Seed:  712
# Loading model from /notebooks/rl2023/ex1/results/model/SpinningReacher-v0_params.pt ...
# Testing...
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/SpinningReacher-v0/test folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Test ep reward: 200 seed: 46
# Test ep reward: 200 seed: 599
# Test ep reward: 200 seed: 54
# Test ep reward: 200 seed: 277
# Test ep reward: 200 seed: 792
# Test ep reward: 200 seed: 567
# Test ep reward: 200 seed: 827
# Test ep reward: 200 seed: 303
# Test ep reward: 200 seed: 175
# Test ep reward: 200 seed: 955
# Average test reward: 200.0 episode length: 200.0

# %% [markdown]
# The agent acting in the environment can be seen using the following command. Change the ```path``` to pick the episode you want to visualize. Bear in mind by default video saving for training is taken every 50 episodes.

# %%
Video(work_dir/'video'/'SpinningReacher-v0'/'test'/f'ex1-episode-0.mp4',
      embed=True, html_attributes="loop autoplay") # Set html_attributes="controls" for video control
# Out:
# <video loop autoplay  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
t.train(cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
      cfg_args=dict(env_name='TargetReacher-v0', train_episodes=500)) # < 5 mins
# Out:
# Numpy/Torch/Random Seed:  386
# Finishing last run (ID:ed42q3yr) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>▁▃▃▂▄▇▇▇▇▇▇███▇▇▄███████████████▆███████</td></tr><tr><td>episodes</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>num_updates</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>timesteps</td><td>█████▂▃▃▄▅▅▂▂▂▂▃█▂▂▁▁▂▂▂▂▂▂▂▂▂▁▂▇▁▁▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>ep_reward</td><td>-30.91431</td></tr><tr><td>episodes</td><td>500</td></tr><tr><td>num_updates</td><td>0</td></tr><tr><td>timesteps</td><td>22</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ex1-TargetReacher-v0-None-1695039101</strong> at: <a href='https://wandb.ai/mayangle/rl_aalto/runs/ed42q3yr' target="_blank">https://wandb.ai/mayangle/rl_aalto/runs/ed42q3yr</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230918_151141-ed42q3yr/logs</code>
# Successfully finished last run (ID:ed42q3yr). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016669353283941746, max=1.0…
# wandb version 0.15.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/notebooks/rl2023/ex1/wandb/run-20230918_153233-e9aog68t</code>
# Syncing run <strong><a href='https://wandb.ai/mayangle/rl_aalto/runs/e9aog68t' target="_blank">ex1-TargetReacher-v0-None-1695040353</a></strong> to <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mayangle/rl_aalto' target="_blank">https://wandb.ai/mayangle/rl_aalto</a>
#  View run at <a href='https://wandb.ai/mayangle/rl_aalto/runs/e9aog68t' target="_blank">https://wandb.ai/mayangle/rl_aalto/runs/e9aog68t</a>
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/TargetReacher-v0/train folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Configuration Settings: {'exp_name': 'ex1', 'seed': None, 'env_name': 'TargetReacher-v0', 'max_episode_steps': 200, 'train_episodes': 500, 'batch_size': 64, 'min_update_samples': 2000, 'testing': False, 'model_path': 'default', 'save_video': True, 'save_model': True, 'save_logging': True, 'silent': False, 'use_wandb': True, 'run_suffix': 0}
# Training device: cpu
# Observation space dimensions: 2
# Action space dimensions: 5
#
# Episode 0 finished. Total reward: -588.6577369906091 (200 timesteps)
# Episode 1 finished. Total reward: -467.6503040445211 (200 timesteps)
# Episode 2 finished. Total reward: -477.5411833333725 (200 timesteps)
# Episode 3 finished. Total reward: -444.1168851308774 (172 timesteps)
# Episode 4 finished. Total reward: -354.7684149254636 (200 timesteps)
# Episode 5 finished. Total reward: -572.2342612281892 (200 timesteps)
# Episode 6 finished. Total reward: -398.15985449608996 (200 timesteps)
# Episode 7 finished. Total reward: -608.7298720561404 (200 timesteps)
# Episode 8 finished. Total reward: -603.9477648083865 (200 timesteps)
# Episode 9 finished. Total reward: -495.40947978796083 (196 timesteps)
# Updating the policy...
# Updating finished!
# Episode 10 finished. Total reward: -645.3028746152061 (200 timesteps)
# Episode 11 finished. Total reward: -513.9182402915189 (200 timesteps)
# Episode 12 finished. Total reward: -455.3437870638004 (200 timesteps)
# Episode 13 finished. Total reward: -412.6628971104841 (200 timesteps)
# Episode 14 finished. Total reward: -301.5954840685696 (124 timesteps)
# Episode 15 finished. Total reward: -462.93169738381766 (200 timesteps)
# Episode 16 finished. Total reward: -308.2074887496304 (200 timesteps)
# Episode 17 finished. Total reward: -315.1948132463815 (136 timesteps)
# Episode 18 finished. Total reward: -460.74678767404447 (200 timesteps)
# Episode 19 finished. Total reward: -140.29718594309745 (75 timesteps)
# Episode 20 finished. Total reward: -573.6543521380687 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 21 finished. Total reward: -479.6996621051802 (200 timesteps)
# Episode 22 finished. Total reward: -200.65381273549534 (84 timesteps)
# Episode 23 finished. Total reward: -409.21063117602165 (200 timesteps)
# Episode 24 finished. Total reward: -394.0654240868077 (200 timesteps)
# Episode 25 finished. Total reward: -99.02468489691876 (44 timesteps)
# Episode 26 finished. Total reward: -91.39530412062226 (43 timesteps)
# Episode 27 finished. Total reward: -405.39529797133105 (200 timesteps)
# Episode 28 finished. Total reward: -67.45219836987913 (36 timesteps)
# Episode 29 finished. Total reward: -267.39822539140107 (183 timesteps)
# Episode 30 finished. Total reward: -393.0213975058707 (200 timesteps)
# Episode 31 finished. Total reward: -622.1172038247237 (200 timesteps)
# Episode 32 finished. Total reward: -378.30834951968336 (200 timesteps)
# Episode 33 finished. Total reward: -591.1313164684497 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 34 finished. Total reward: -202.20590338843257 (130 timesteps)
# Episode 35 finished. Total reward: -300.58921990574066 (174 timesteps)
# Episode 36 finished. Total reward: -180.91156027804595 (72 timesteps)
# Episode 37 finished. Total reward: -468.57600011629677 (200 timesteps)
# Episode 38 finished. Total reward: -96.71055557053593 (53 timesteps)
# Episode 39 finished. Total reward: -435.26373203305434 (200 timesteps)
# Episode 40 finished. Total reward: -120.1032668956792 (55 timesteps)
# Episode 41 finished. Total reward: -360.69042867789136 (200 timesteps)
# Episode 42 finished. Total reward: -466.87574741337227 (200 timesteps)
# Episode 43 finished. Total reward: -422.33016100375437 (200 timesteps)
# Episode 44 finished. Total reward: -394.0525193584659 (200 timesteps)
# Episode 45 finished. Total reward: -147.81265460376997 (76 timesteps)
# Episode 46 finished. Total reward: -67.88795180416702 (43 timesteps)
# Episode 47 finished. Total reward: -99.62617587398515 (41 timesteps)
# Episode 48 finished. Total reward: -77.32674543521215 (47 timesteps)
# Episode 49 finished. Total reward: -306.2249537980064 (135 timesteps)
# Updating the policy...
# Updating finished!
# Episode 50 finished. Total reward: -413.13859137856974 (148 timesteps)
# Episode 51 finished. Total reward: -316.5677645759801 (181 timesteps)
# Episode 52 finished. Total reward: -167.44744098778256 (70 timesteps)
# Episode 53 finished. Total reward: -432.1278356692014 (200 timesteps)
# Episode 54 finished. Total reward: -56.75754337786525 (28 timesteps)
# Episode 55 finished. Total reward: -65.58467928533202 (38 timesteps)
# Episode 56 finished. Total reward: -70.33117559515343 (34 timesteps)
# Episode 57 finished. Total reward: -184.97220107793692 (123 timesteps)
# Episode 58 finished. Total reward: -115.2474629182799 (58 timesteps)
# Episode 59 finished. Total reward: -323.43556052143896 (177 timesteps)
# Episode 60 finished. Total reward: -246.99852293059237 (141 timesteps)
# Episode 61 finished. Total reward: -76.86866713983451 (47 timesteps)
# Episode 62 finished. Total reward: -54.8444473516441 (31 timesteps)
# Episode 63 finished. Total reward: -397.2245482572131 (200 timesteps)
# Episode 64 finished. Total reward: -271.026992766295 (131 timesteps)
# Episode 65 finished. Total reward: -92.47504901110628 (52 timesteps)
# Episode 66 finished. Total reward: -107.20739917538289 (50 timesteps)
# Episode 67 finished. Total reward: -165.62860027600638 (98 timesteps)
# Episode 68 finished. Total reward: -63.72984165509369 (32 timesteps)
# Episode 69 finished. Total reward: -377.706670447993 (200 timesteps)
# Episode 70 finished. Total reward: -84.575267466821 (38 timesteps)
# Updating the policy...
# Updating finished!
# Episode 71 finished. Total reward: -264.27683963719545 (165 timesteps)
# Episode 72 finished. Total reward: -62.5581538071507 (30 timesteps)
# Episode 73 finished. Total reward: -386.62155115932654 (200 timesteps)
# Episode 74 finished. Total reward: -36.57165846648444 (22 timesteps)
# Episode 75 finished. Total reward: -41.7329493237306 (29 timesteps)
# Episode 76 finished. Total reward: -332.91657240626455 (200 timesteps)
# Episode 77 finished. Total reward: -115.1384601243532 (66 timesteps)
# Episode 78 finished. Total reward: -351.93947890623537 (200 timesteps)
# Episode 79 finished. Total reward: -358.9839090971475 (200 timesteps)
# Episode 80 finished. Total reward: -40.5686226664021 (21 timesteps)
# Episode 81 finished. Total reward: -360.6149153194717 (200 timesteps)
# Episode 82 finished. Total reward: -345.1005147306266 (200 timesteps)
# Episode 83 finished. Total reward: -92.39082400720642 (64 timesteps)
# Episode 84 finished. Total reward: -370.1720827357287 (200 timesteps)
# Episode 85 finished. Total reward: -119.7379979255517 (69 timesteps)
# Episode 86 finished. Total reward: -165.17632661161815 (104 timesteps)
# Episode 87 finished. Total reward: -47.563341957904505 (26 timesteps)
# Updating the policy...
# Updating finished!
# Episode 88 finished. Total reward: -42.973074029017525 (20 timesteps)
# Episode 89 finished. Total reward: -273.5546669736764 (152 timesteps)
# Episode 90 finished. Total reward: -317.5581466117283 (200 timesteps)
# Episode 91 finished. Total reward: -363.5221023166997 (200 timesteps)
# Episode 92 finished. Total reward: -43.411045622290374 (20 timesteps)
# Episode 93 finished. Total reward: -101.10273275344277 (50 timesteps)
# Episode 94 finished. Total reward: -43.29464076308475 (25 timesteps)
# Episode 95 finished. Total reward: -38.05985598024235 (21 timesteps)
# Episode 96 finished. Total reward: -55.630287128400354 (26 timesteps)
# Episode 97 finished. Total reward: -34.45816192284334 (18 timesteps)
# Episode 98 finished. Total reward: -211.24022050387393 (134 timesteps)
# Episode 99 finished. Total reward: -49.72337843352226 (30 timesteps)
# Episode 100 finished. Total reward: -58.22625562267567 (30 timesteps)
# Episode 101 finished. Total reward: -326.36700022195913 (197 timesteps)
# Episode 102 finished. Total reward: -74.3673977183815 (35 timesteps)
# Episode 103 finished. Total reward: -311.80369965025 (200 timesteps)
# Episode 104 finished. Total reward: -282.00998452003626 (163 timesteps)
# Episode 105 finished. Total reward: -43.6018067191106 (22 timesteps)
# Episode 106 finished. Total reward: -338.8980531710685 (195 timesteps)
# Episode 107 finished. Total reward: -311.0431884948013 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 108 finished. Total reward: -331.9297796237861 (200 timesteps)
# Episode 109 finished. Total reward: -131.09689585306648 (68 timesteps)
# Episode 110 finished. Total reward: -72.74536367146223 (33 timesteps)
# Episode 111 finished. Total reward: -50.88482636219886 (27 timesteps)
# Episode 112 finished. Total reward: -54.105151359078214 (32 timesteps)
# Episode 113 finished. Total reward: -47.516230191769836 (24 timesteps)
# Episode 114 finished. Total reward: -276.5648697951291 (170 timesteps)
# Episode 115 finished. Total reward: -47.59265034107038 (27 timesteps)
# Episode 116 finished. Total reward: -64.60946776867789 (28 timesteps)
# Episode 117 finished. Total reward: -66.99571177435455 (36 timesteps)
# Episode 118 finished. Total reward: -337.18012895336807 (200 timesteps)
# Episode 119 finished. Total reward: -262.46797277998763 (139 timesteps)
# Episode 120 finished. Total reward: -71.50756826272254 (40 timesteps)
# Episode 121 finished. Total reward: -32.65124638372878 (17 timesteps)
# Episode 122 finished. Total reward: -319.10997040015684 (194 timesteps)
# Episode 123 finished. Total reward: -270.30465544430206 (153 timesteps)
# Episode 124 finished. Total reward: -416.45176781368804 (200 timesteps)
# Episode 125 finished. Total reward: -31.22466343298104 (17 timesteps)
# Episode 126 finished. Total reward: -43.93213889156057 (22 timesteps)
# Episode 127 finished. Total reward: -361.7514217925203 (200 timesteps)
# Episode 128 finished. Total reward: -334.5451959046194 (200 timesteps)
# Episode 129 finished. Total reward: -38.516171491941414 (18 timesteps)
# Updating the policy...
# Updating finished!
# Episode 130 finished. Total reward: -329.64776684479943 (200 timesteps)
# Episode 131 finished. Total reward: -31.64028028866849 (22 timesteps)
# Episode 132 finished. Total reward: -47.91363573007336 (26 timesteps)
# Episode 133 finished. Total reward: -432.2848940530429 (200 timesteps)
# Episode 134 finished. Total reward: -318.9964156325227 (200 timesteps)
# Episode 135 finished. Total reward: -43.886340593125404 (21 timesteps)
# Episode 136 finished. Total reward: -43.51000696708424 (21 timesteps)
# Episode 137 finished. Total reward: -40.291251690932455 (30 timesteps)
# Episode 138 finished. Total reward: -297.7286200829529 (200 timesteps)
# Episode 139 finished. Total reward: -28.541040388798013 (15 timesteps)
# Episode 140 finished. Total reward: -323.0604519498329 (200 timesteps)
# Episode 141 finished. Total reward: -45.832817881357386 (26 timesteps)
# Episode 142 finished. Total reward: -202.42268331169439 (106 timesteps)
# Episode 143 finished. Total reward: -36.71144363882973 (17 timesteps)
# Episode 144 finished. Total reward: -61.57780205199058 (30 timesteps)
# Episode 145 finished. Total reward: -32.77329107682895 (18 timesteps)
# Episode 146 finished. Total reward: -307.027224194318 (200 timesteps)
# Episode 147 finished. Total reward: -180.18903261995095 (97 timesteps)
# Episode 148 finished. Total reward: -337.30253694637224 (200 timesteps)
# Episode 149 finished. Total reward: -164.3900965906161 (106 timesteps)
# Episode 150 finished. Total reward: -35.30439160462758 (18 timesteps)
# Episode 151 finished. Total reward: -38.99227626662178 (22 timesteps)
# Updating the policy...
# Updating finished!
# Episode 152 finished. Total reward: -292.9779931987311 (200 timesteps)
# Episode 153 finished. Total reward: -30.315524080237072 (16 timesteps)
# Episode 154 finished. Total reward: -31.00936950944953 (19 timesteps)
# Episode 155 finished. Total reward: -331.66437432365154 (200 timesteps)
# Episode 156 finished. Total reward: -180.65566535551542 (91 timesteps)
# Episode 157 finished. Total reward: -312.43272904940966 (200 timesteps)
# Episode 158 finished. Total reward: -40.76701752533152 (20 timesteps)
# Episode 159 finished. Total reward: -38.05370973483055 (21 timesteps)
# Episode 160 finished. Total reward: -64.99632843912069 (35 timesteps)
# Episode 161 finished. Total reward: -320.63498836011024 (200 timesteps)
# Episode 162 finished. Total reward: -146.6859958698214 (84 timesteps)
# Episode 163 finished. Total reward: -37.22424151432121 (19 timesteps)
# Episode 164 finished. Total reward: -369.147200777103 (200 timesteps)
# Episode 165 finished. Total reward: -301.1676772002552 (200 timesteps)
# Episode 166 finished. Total reward: -189.80855334765926 (113 timesteps)
# Episode 167 finished. Total reward: -43.791734240120896 (24 timesteps)
# Episode 168 finished. Total reward: -46.41603021200769 (25 timesteps)
# Episode 169 finished. Total reward: -37.833410662145354 (23 timesteps)
# Episode 170 finished. Total reward: -368.2375892883453 (200 timesteps)
# Episode 171 finished. Total reward: -39.834727409434976 (24 timesteps)
# Episode 172 finished. Total reward: -49.242391266357366 (26 timesteps)
# Episode 173 finished. Total reward: -29.274163671881396 (17 timesteps)
# Episode 174 finished. Total reward: -35.70870761066409 (18 timesteps)
# Updating the policy...
# Updating finished!
# Episode 175 finished. Total reward: -170.57719436635833 (114 timesteps)
# Episode 176 finished. Total reward: -203.71551767322396 (115 timesteps)
# Episode 177 finished. Total reward: -308.65313983879986 (200 timesteps)
# Episode 178 finished. Total reward: -43.56518938164289 (23 timesteps)
# Episode 179 finished. Total reward: -337.7269276002777 (200 timesteps)
# Episode 180 finished. Total reward: -35.5793690643894 (20 timesteps)
# Episode 181 finished. Total reward: -339.15029992217717 (200 timesteps)
# Episode 182 finished. Total reward: -41.972458287576984 (20 timesteps)
# Episode 183 finished. Total reward: -40.54468155705377 (22 timesteps)
# Episode 184 finished. Total reward: -124.82974642540785 (79 timesteps)
# Episode 185 finished. Total reward: -308.47825428725224 (200 timesteps)
# Episode 186 finished. Total reward: -28.440668599917988 (15 timesteps)
# Episode 187 finished. Total reward: -249.10493066149255 (127 timesteps)
# Episode 188 finished. Total reward: -32.38933550495353 (17 timesteps)
# Episode 189 finished. Total reward: -69.14934077363486 (32 timesteps)
# Episode 190 finished. Total reward: -33.48689484467869 (21 timesteps)
# Episode 191 finished. Total reward: -334.44297883002184 (200 timesteps)
# Episode 192 finished. Total reward: -206.45019453710924 (138 timesteps)
# Episode 193 finished. Total reward: -311.09595170165545 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 194 finished. Total reward: -315.1891571093751 (200 timesteps)
# Episode 195 finished. Total reward: -34.76147955553847 (19 timesteps)
# Episode 196 finished. Total reward: -32.30762552144751 (17 timesteps)
# Episode 197 finished. Total reward: -186.601723451184 (96 timesteps)
# Episode 198 finished. Total reward: -37.498994815863135 (18 timesteps)
# Episode 199 finished. Total reward: -35.93196659610699 (20 timesteps)
# Episode 200 finished. Total reward: -353.3005515298238 (200 timesteps)
# Episode 201 finished. Total reward: -35.380843243175285 (19 timesteps)
# Episode 202 finished. Total reward: -30.446973802897617 (17 timesteps)
# Episode 203 finished. Total reward: -41.111079838492856 (21 timesteps)
# Episode 204 finished. Total reward: -33.88139305095567 (18 timesteps)
# Episode 205 finished. Total reward: -331.5405933507577 (194 timesteps)
# Episode 206 finished. Total reward: -34.12590577557041 (17 timesteps)
# Episode 207 finished. Total reward: -141.91677134458598 (75 timesteps)
# Episode 208 finished. Total reward: -38.488216141938125 (22 timesteps)
# Episode 209 finished. Total reward: -36.221779107280234 (18 timesteps)
# Episode 210 finished. Total reward: -44.841664306201324 (22 timesteps)
# Episode 211 finished. Total reward: -35.50877346638298 (20 timesteps)
# Episode 212 finished. Total reward: -44.95445163681562 (23 timesteps)
# Episode 213 finished. Total reward: -40.136620445128656 (20 timesteps)
# Episode 214 finished. Total reward: -329.2982083054597 (200 timesteps)
# Episode 215 finished. Total reward: -283.78944648114657 (200 timesteps)
# Episode 216 finished. Total reward: -312.8575821333402 (200 timesteps)
# Episode 217 finished. Total reward: -59.632748815548524 (34 timesteps)
# Episode 218 finished. Total reward: -28.140579151052336 (17 timesteps)
# Episode 219 finished. Total reward: -36.34756283616038 (19 timesteps)
# Episode 220 finished. Total reward: -158.22334653111602 (89 timesteps)
# Episode 221 finished. Total reward: -39.34456787113388 (21 timesteps)
# Episode 222 finished. Total reward: -318.15322700425463 (186 timesteps)
# Episode 223 finished. Total reward: -53.53757538179359 (27 timesteps)
# Episode 224 finished. Total reward: -34.44758671119695 (17 timesteps)
# Episode 225 finished. Total reward: -29.06395385996626 (15 timesteps)
# Updating the policy...
# Updating finished!
# Episode 226 finished. Total reward: -317.87201874049464 (200 timesteps)
# Episode 227 finished. Total reward: -299.1641347804766 (200 timesteps)
# Episode 228 finished. Total reward: -29.56839944563006 (15 timesteps)
# Episode 229 finished. Total reward: -299.0278399355165 (200 timesteps)
# Episode 230 finished. Total reward: -145.65565699179731 (92 timesteps)
# Episode 231 finished. Total reward: -35.04654245618346 (18 timesteps)
# Episode 232 finished. Total reward: -33.082196381207694 (18 timesteps)
# Episode 233 finished. Total reward: -30.77745559622488 (16 timesteps)
# Episode 234 finished. Total reward: -303.37200512492717 (200 timesteps)
# Episode 235 finished. Total reward: -37.51448808145709 (18 timesteps)
# Episode 236 finished. Total reward: -40.94727151791138 (22 timesteps)
# Episode 237 finished. Total reward: -38.78037967672342 (21 timesteps)
# Episode 238 finished. Total reward: -32.41039019084092 (17 timesteps)
# Episode 239 finished. Total reward: -36.36766021243799 (19 timesteps)
# Episode 240 finished. Total reward: -343.3197887169142 (200 timesteps)
# Episode 241 finished. Total reward: -29.892975122249776 (16 timesteps)
# Episode 242 finished. Total reward: -333.839106614696 (200 timesteps)
# Episode 243 finished. Total reward: -34.236591505271676 (22 timesteps)
# Episode 244 finished. Total reward: -41.62318563155932 (23 timesteps)
# Episode 245 finished. Total reward: -324.95461188065684 (200 timesteps)
# Episode 246 finished. Total reward: -29.125366417951955 (16 timesteps)
# Episode 247 finished. Total reward: -293.83281771826483 (200 timesteps)
# Episode 248 finished. Total reward: -36.26430974398183 (19 timesteps)
# Episode 249 finished. Total reward: -31.101215321781538 (16 timesteps)
# Episode 250 finished. Total reward: -33.24209615713503 (19 timesteps)
# Updating the policy...
# Updating finished!
# Episode 251 finished. Total reward: -124.77191770277899 (80 timesteps)
# Episode 252 finished. Total reward: -219.62767781240606 (123 timesteps)
# Episode 253 finished. Total reward: -30.86502359693969 (16 timesteps)
# Episode 254 finished. Total reward: -294.3355015696615 (200 timesteps)
# Episode 255 finished. Total reward: -289.243316356002 (200 timesteps)
# Episode 256 finished. Total reward: -30.121682613549673 (16 timesteps)
# Episode 257 finished. Total reward: -319.0036766434843 (200 timesteps)
# Episode 258 finished. Total reward: -29.128863501083615 (17 timesteps)
# Episode 259 finished. Total reward: -33.236484706434496 (19 timesteps)
# Episode 260 finished. Total reward: -315.9957070604149 (200 timesteps)
# Episode 261 finished. Total reward: -141.89697998405705 (85 timesteps)
# Episode 262 finished. Total reward: -37.00518235921854 (21 timesteps)
# Episode 263 finished. Total reward: -40.49151200541014 (21 timesteps)
# Episode 264 finished. Total reward: -164.45149386715414 (92 timesteps)
# Episode 265 finished. Total reward: -29.58695287749242 (16 timesteps)
# Episode 266 finished. Total reward: -42.5522147447809 (21 timesteps)
# Episode 267 finished. Total reward: -293.9049199635522 (200 timesteps)
# Episode 268 finished. Total reward: -416.04460224824095 (200 timesteps)
# Episode 269 finished. Total reward: -32.616211218604015 (17 timesteps)
# Episode 270 finished. Total reward: -195.91137633012642 (128 timesteps)
# Episode 271 finished. Total reward: -297.6518867568923 (200 timesteps)
# Updating the policy...
# Updating finished!
# Episode 272 finished. Total reward: -32.667640096008824 (17 timesteps)
# Episode 273 finished. Total reward: -303.365586221291 (200 timesteps)
# Episode 274 finished. Total reward: -29.168421582928907 (18 timesteps)
# Episode 275 finished. Total reward: -299.0669463842829 (200 timesteps)
# Episode 276 finished. Total reward: -280.9854341170406 (200 timesteps)
# Episode 277 finished. Total reward: -291.08257053537625 (200 timesteps)
# Episode 278 finished. Total reward: -141.78127571392352 (88 timesteps)
# Episode 279 finished. Total reward: -31.364524249289992 (16 timesteps)
# Episode 280 finished. Total reward: -288.6817637874289 (200 timesteps)
# Episode 281 finished. Total reward: -206.36751942890461 (134 timesteps)
# Episode 282 finished. Total reward: -292.68769423711296 (200 timesteps)
# Episode 283 finished. Total reward: -38.02991265942343 (22 timesteps)
# Episode 284 finished. Total reward: -31.227157203190743 (17 timesteps)
# Episode 285 finished. Total reward: -293.10810035777007 (200 timesteps)
# Episode 286 finished. Total reward: -34.233391100106104 (17 timesteps)
# Episode 287 finished. Total reward: -146.18296641994664 (87 timesteps)
# Episode 288 finished. Total reward: -29.807216484829617 (17 timesteps)
# Updating the policy...
# Updating finished!
# Episode 289 finished. Total reward: -311.57481452551946 (200 timesteps)
# Episode 290 finished. Total reward: -38.03190625920913 (20 timesteps)
# Episode 291 finished. Total reward: -30.69205853600622 (17 timesteps)
# Episode 292 finished. Total reward: -295.44195859347633 (200 timesteps)
# Episode 293 finished. Total reward: -28.0472740698401 (18 timesteps)
# Episode 294 finished. Total reward: -29.365422980056646 (16 timesteps)
# Episode 295 finished. Total reward: -34.3365139381889 (21 timesteps)
# Episode 296 finished. Total reward: -323.8598731955615 (200 timesteps)
# Episode 297 finished. Total reward: -311.4696147249366 (200 timesteps)
# Episode 298 finished. Total reward: -30.409507617567428 (16 timesteps)
# Episode 299 finished. Total reward: -47.82343747660031 (24 timesteps)
# Episode 300 finished. Total reward: -35.04579268588088 (17 timesteps)
# Episode 301 finished. Total reward: -311.48621394948066 (200 timesteps)
# Episode 302 finished. Total reward: -155.97051972574516 (78 timesteps)
# Episode 303 finished. Total reward: -32.362082957182054 (18 timesteps)
# Episode 304 finished. Total reward: -141.50405067808586 (75 timesteps)
# Episode 305 finished. Total reward: -29.77612932683616 (15 timesteps)
# Episode 306 finished. Total reward: -293.40719128972876 (200 timesteps)
# Episode 307 finished. Total reward: -304.5934107704028 (200 timesteps)
# Episode 308 finished. Total reward: -293.23975455707546 (200 timesteps)
# Episode 309 finished. Total reward: -40.12619772446913 (20 timesteps)
# Episode 310 finished. Total reward: -235.76273879796284 (119 timesteps)
# Episode 311 finished. Total reward: -28.792725124289635 (16 timesteps)
# Episode 312 finished. Total reward: -34.26746891076343 (18 timesteps)
# Episode 313 finished. Total reward: -35.57035382763864 (17 timesteps)
# Episode 314 finished. Total reward: -30.383037491599836 (16 timesteps)
# Updating the policy...
# Updating finished!
# Episode 315 finished. Total reward: -302.0968845224003 (200 timesteps)
# Episode 316 finished. Total reward: -29.60579321283155 (16 timesteps)
# Episode 317 finished. Total reward: -32.07047142180169 (16 timesteps)
# Episode 318 finished. Total reward: -249.70143100164245 (129 timesteps)
# Episode 319 finished. Total reward: -307.6630647804887 (200 timesteps)
# Episode 320 finished. Total reward: -28.634850414516652 (17 timesteps)
# Episode 321 finished. Total reward: -366.2504246144304 (200 timesteps)
# Episode 322 finished. Total reward: -37.128063975481425 (18 timesteps)
# Episode 323 finished. Total reward: -29.41207038332758 (15 timesteps)
# Episode 324 finished. Total reward: -29.864332964578093 (16 timesteps)
# Episode 325 finished. Total reward: -31.31348306412255 (16 timesteps)
# Episode 326 finished. Total reward: -289.3351095929647 (200 timesteps)
# Episode 327 finished. Total reward: -29.318337963662604 (16 timesteps)
# Episode 328 finished. Total reward: -29.628357151458378 (15 timesteps)
# Episode 329 finished. Total reward: -280.53555546524194 (200 timesteps)
# Episode 330 finished. Total reward: -33.20927470658584 (18 timesteps)
# Episode 331 finished. Total reward: -299.7807924996695 (200 timesteps)
# Episode 332 finished. Total reward: -298.2571772564736 (200 timesteps)
# Episode 333 finished. Total reward: -29.684269539272012 (16 timesteps)
# Episode 334 finished. Total reward: -34.02033877529463 (18 timesteps)
# Episode 335 finished. Total reward: -36.3678305630462 (18 timesteps)
# Episode 336 finished. Total reward: -284.4564512608974 (200 timesteps)
# Episode 337 finished. Total reward: -27.705526704327486 (14 timesteps)
# Updating the policy...
# Updating finished!
# Episode 338 finished. Total reward: -167.14044333748788 (108 timesteps)
# Episode 339 finished. Total reward: -29.86843536321753 (17 timesteps)
# Episode 340 finished. Total reward: -275.4466045846536 (179 timesteps)
# Episode 341 finished. Total reward: -317.15580141087344 (200 timesteps)
# Episode 342 finished. Total reward: -312.29657016423675 (200 timesteps)
# Episode 343 finished. Total reward: -33.67872884519505 (18 timesteps)
# Episode 344 finished. Total reward: -32.875540817177686 (21 timesteps)
# Episode 345 finished. Total reward: -26.870990556794688 (14 timesteps)
# Episode 346 finished. Total reward: -34.62525736493154 (18 timesteps)
# Episode 347 finished. Total reward: -297.54173474984896 (200 timesteps)
# Episode 348 finished. Total reward: -31.16348485522113 (16 timesteps)
# Episode 349 finished. Total reward: -215.22416133284136 (133 timesteps)
# Episode 350 finished. Total reward: -30.0388531397934 (16 timesteps)
# Episode 351 finished. Total reward: -29.511664083603247 (16 timesteps)
# Episode 352 finished. Total reward: -42.549574702989865 (21 timesteps)
# Episode 353 finished. Total reward: -30.784194607852527 (15 timesteps)
# Episode 354 finished. Total reward: -40.913817984262465 (26 timesteps)
# Episode 355 finished. Total reward: -202.22804276915468 (141 timesteps)
# Episode 356 finished. Total reward: -30.277068504256697 (15 timesteps)
# Episode 357 finished. Total reward: -34.02006054495422 (17 timesteps)
# Episode 358 finished. Total reward: -255.51520794441907 (159 timesteps)
# Episode 359 finished. Total reward: -30.987798075484353 (16 timesteps)
# Episode 360 finished. Total reward: -27.714393128785208 (15 timesteps)
# Episode 361 finished. Total reward: -30.150153876202886 (16 timesteps)
# Episode 362 finished. Total reward: -292.8311011666825 (200 timesteps)
# Episode 363 finished. Total reward: -33.54712145397525 (17 timesteps)
# Episode 364 finished. Total reward: -27.75123094332969 (15 timesteps)
# Episode 365 finished. Total reward: -34.69124427765849 (17 timesteps)
# Episode 366 finished. Total reward: -33.049634087114626 (19 timesteps)
# Episode 367 finished. Total reward: -29.85353665802984 (15 timesteps)
# Updating the policy...
# Updating finished!
# Episode 368 finished. Total reward: -312.82233393533244 (200 timesteps)
# Episode 369 finished. Total reward: -31.6329214075497 (16 timesteps)
# Episode 370 finished. Total reward: -321.9400134071705 (200 timesteps)
# Episode 371 finished. Total reward: -29.390144058948483 (15 timesteps)
# Episode 372 finished. Total reward: -32.74054487837483 (21 timesteps)
# Episode 373 finished. Total reward: -26.747517570287254 (14 timesteps)
# Episode 374 finished. Total reward: -31.390186993437794 (18 timesteps)
# Episode 375 finished. Total reward: -310.04871338509787 (200 timesteps)
# Episode 376 finished. Total reward: -320.304899762241 (200 timesteps)
# Episode 377 finished. Total reward: -30.41914514106457 (17 timesteps)
# Episode 378 finished. Total reward: -296.05850662657684 (200 timesteps)
# Episode 379 finished. Total reward: -35.94582764602387 (18 timesteps)
# Episode 380 finished. Total reward: -35.85917383227097 (18 timesteps)
# Episode 381 finished. Total reward: -336.3336940958288 (200 timesteps)
# Episode 382 finished. Total reward: -309.4037781378493 (200 timesteps)
# Episode 383 finished. Total reward: -32.67971820109475 (17 timesteps)
# Episode 384 finished. Total reward: -30.298115256669103 (15 timesteps)
# Episode 385 finished. Total reward: -31.081988227148152 (15 timesteps)
# Episode 386 finished. Total reward: -319.348926864624 (200 timesteps)
# Episode 387 finished. Total reward: -28.689651868205715 (15 timesteps)
# Episode 388 finished. Total reward: -27.104061616376043 (15 timesteps)
# Episode 389 finished. Total reward: -27.996665514112486 (15 timesteps)
# Episode 390 finished. Total reward: -135.7122982702512 (81 timesteps)
# Episode 391 finished. Total reward: -328.4348431191345 (200 timesteps)
# Episode 392 finished. Total reward: -29.760524457474315 (16 timesteps)
# Episode 393 finished. Total reward: -29.282098526733275 (15 timesteps)
# Episode 394 finished. Total reward: -29.666394254589967 (16 timesteps)
# Episode 395 finished. Total reward: -29.48139662351171 (16 timesteps)
# Episode 396 finished. Total reward: -31.93977933001613 (18 timesteps)
# Updating the policy...
# Updating finished!
# Episode 397 finished. Total reward: -36.4564873970034 (22 timesteps)
# Episode 398 finished. Total reward: -283.02309625474794 (192 timesteps)
# Episode 399 finished. Total reward: -27.750391640615018 (15 timesteps)
# Episode 400 finished. Total reward: -29.99616830410788 (15 timesteps)
# Episode 401 finished. Total reward: -30.831935038496145 (17 timesteps)
# Episode 402 finished. Total reward: -29.399282167871963 (15 timesteps)
# Episode 403 finished. Total reward: -26.928876857663 (15 timesteps)
# Episode 404 finished. Total reward: -28.089191967249658 (15 timesteps)
# Episode 405 finished. Total reward: -26.754743910981286 (14 timesteps)
# Episode 406 finished. Total reward: -25.920748065999103 (14 timesteps)
# Episode 407 finished. Total reward: -36.038279893788236 (19 timesteps)
# Episode 408 finished. Total reward: -31.224827946148103 (16 timesteps)
# Episode 409 finished. Total reward: -29.333486573703375 (16 timesteps)
# Episode 410 finished. Total reward: -37.08445373604672 (18 timesteps)
# Episode 411 finished. Total reward: -298.89412139774737 (200 timesteps)
# Episode 412 finished. Total reward: -31.877425542226735 (16 timesteps)
# Episode 413 finished. Total reward: -38.46906017832962 (20 timesteps)
# Episode 414 finished. Total reward: -32.03018754149642 (16 timesteps)
# Episode 415 finished. Total reward: -33.74917051169109 (19 timesteps)
# Episode 416 finished. Total reward: -29.795936655906555 (16 timesteps)
# Episode 417 finished. Total reward: -29.568739602045 (15 timesteps)
# Episode 418 finished. Total reward: -31.756798767572636 (17 timesteps)
# Episode 419 finished. Total reward: -28.99915997701394 (17 timesteps)
# Episode 420 finished. Total reward: -32.32826736489318 (17 timesteps)
# Episode 421 finished. Total reward: -153.0564258599031 (84 timesteps)
# Episode 422 finished. Total reward: -30.09927943087865 (20 timesteps)
# Episode 423 finished. Total reward: -29.56517798569117 (15 timesteps)
# Episode 424 finished. Total reward: -33.19775703251502 (17 timesteps)
# Episode 425 finished. Total reward: -313.96331954059855 (200 timesteps)
# Episode 426 finished. Total reward: -33.52341017357017 (20 timesteps)
# Episode 427 finished. Total reward: -262.9218625225505 (172 timesteps)
# Episode 428 finished. Total reward: -38.29138371429416 (21 timesteps)
# Episode 429 finished. Total reward: -27.86035670913108 (16 timesteps)
# Episode 430 finished. Total reward: -29.065059544666987 (15 timesteps)
# Episode 431 finished. Total reward: -29.73552379263919 (16 timesteps)
# Episode 432 finished. Total reward: -31.886127452157254 (16 timesteps)
# Episode 433 finished. Total reward: -290.0948528347857 (200 timesteps)
# Episode 434 finished. Total reward: -31.88174176852433 (17 timesteps)
# Episode 435 finished. Total reward: -29.757365650268795 (15 timesteps)
# Episode 436 finished. Total reward: -296.6111692184684 (200 timesteps)
# Episode 437 finished. Total reward: -38.44801228875995 (23 timesteps)
# Updating the policy...
# Updating finished!
# Episode 438 finished. Total reward: -323.3535683820667 (200 timesteps)
# Episode 439 finished. Total reward: -406.7107148884586 (200 timesteps)
# Episode 440 finished. Total reward: -33.17226369539033 (18 timesteps)
# Episode 441 finished. Total reward: -32.149071458035166 (17 timesteps)
# Episode 442 finished. Total reward: -26.451038726866102 (14 timesteps)
# Episode 443 finished. Total reward: -30.275603579881945 (16 timesteps)
# Episode 444 finished. Total reward: -29.985012437199686 (16 timesteps)
# Episode 445 finished. Total reward: -28.83857397586763 (17 timesteps)
# Episode 446 finished. Total reward: -34.30348530230083 (18 timesteps)
# Episode 447 finished. Total reward: -28.096425567579754 (15 timesteps)
# Episode 448 finished. Total reward: -30.06941554357368 (17 timesteps)
# Episode 449 finished. Total reward: -29.306700297577326 (15 timesteps)
# Episode 450 finished. Total reward: -254.3634279751237 (154 timesteps)
# Episode 451 finished. Total reward: -28.107640808333617 (15 timesteps)
# Episode 452 finished. Total reward: -32.71293071957064 (17 timesteps)
# Episode 453 finished. Total reward: -28.335242246851767 (15 timesteps)
# Episode 454 finished. Total reward: -149.0099275703985 (84 timesteps)
# Episode 455 finished. Total reward: -149.50931897715404 (83 timesteps)
# Episode 456 finished. Total reward: -135.52491441114515 (73 timesteps)
# Episode 457 finished. Total reward: -30.35316229472593 (16 timesteps)
# Episode 458 finished. Total reward: -129.7139692719083 (78 timesteps)
# Episode 459 finished. Total reward: -33.964562935274614 (17 timesteps)
# Episode 460 finished. Total reward: -30.157871544736576 (16 timesteps)
# Episode 461 finished. Total reward: -32.205499845818956 (16 timesteps)
# Episode 462 finished. Total reward: -340.8120973084871 (200 timesteps)
# Episode 463 finished. Total reward: -29.300012063784855 (15 timesteps)
# Episode 464 finished. Total reward: -29.28798597888419 (15 timesteps)
# Episode 465 finished. Total reward: -29.819835808901704 (15 timesteps)
# Episode 466 finished. Total reward: -30.44686437175816 (17 timesteps)
# Episode 467 finished. Total reward: -30.05203831840431 (15 timesteps)
# Episode 468 finished. Total reward: -320.84520911993667 (200 timesteps)
# Episode 469 finished. Total reward: -35.40593719446867 (18 timesteps)
# Episode 470 finished. Total reward: -31.609657725933875 (16 timesteps)
# Episode 471 finished. Total reward: -26.672694028223518 (15 timesteps)
# Episode 472 finished. Total reward: -26.024406464946264 (15 timesteps)
# Episode 473 finished. Total reward: -27.708766383611735 (15 timesteps)
# Episode 474 finished. Total reward: -30.944015518174805 (16 timesteps)
# Episode 475 finished. Total reward: -318.90475034998906 (200 timesteps)
# Episode 476 finished. Total reward: -343.39110746144706 (200 timesteps)
# Episode 477 finished. Total reward: -27.419583326572855 (14 timesteps)
# Episode 478 finished. Total reward: -32.17298455484298 (18 timesteps)
# Episode 479 finished. Total reward: -28.258476310505106 (15 timesteps)
# Episode 480 finished. Total reward: -38.28347437438064 (19 timesteps)
# Updating the policy...
# Updating finished!
# Episode 481 finished. Total reward: -336.5134146900297 (200 timesteps)
# Episode 482 finished. Total reward: -28.94783133641744 (17 timesteps)
# Episode 483 finished. Total reward: -27.91398564695945 (15 timesteps)
# Episode 484 finished. Total reward: -128.87309434658184 (69 timesteps)
# Episode 485 finished. Total reward: -28.051894647323525 (15 timesteps)
# Episode 486 finished. Total reward: -28.963747450459092 (15 timesteps)
# Episode 487 finished. Total reward: -194.19845674432514 (109 timesteps)
# Episode 488 finished. Total reward: -30.936546812222872 (16 timesteps)
# Episode 489 finished. Total reward: -26.38483327954941 (15 timesteps)
# Episode 490 finished. Total reward: -29.547950341764952 (15 timesteps)
# Episode 491 finished. Total reward: -29.432783294215753 (15 timesteps)
# Episode 492 finished. Total reward: -33.85311008299158 (17 timesteps)
# Episode 493 finished. Total reward: -166.97163775760419 (112 timesteps)
# Episode 494 finished. Total reward: -33.835407612502685 (17 timesteps)
# Episode 495 finished. Total reward: -29.378736495557813 (16 timesteps)
# Episode 496 finished. Total reward: -25.160179454037227 (14 timesteps)
# Episode 497 finished. Total reward: -33.83497050553592 (18 timesteps)
# Episode 498 finished. Total reward: -29.493795535954526 (15 timesteps)
# Episode 499 finished. Total reward: -29.130431658476873 (15 timesteps)
# Episode 500 finished. Total reward: -31.367303401675503 (16 timesteps)
# Model saved to /notebooks/rl2023/ex1/results/model/TargetReacher-v0_params.pt
# ------Training finished.------

# %%
t.test(episodes=10, cfg_path=Path().cwd()/'cfg'/'reacher_v1.yaml', 
       cfg_args=dict(env_name='TargetReacher-v0', seed=None, testing=True, use_wandb=False))
# Out:
# Numpy/Torch/Random Seed:  32
# Loading model from /notebooks/rl2023/ex1/results/model/TargetReacher-v0_params.pt ...
# Testing...
# /opt/software/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /notebooks/rl2023/ex1/results/video/TargetReacher-v0/test folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Test ep reward: -26.481314846208463 seed: 728
# Test ep reward: -29.723081287444582 seed: 556
# Test ep reward: -28.96849896636418 seed: 902
# Test ep reward: -30.187589084193302 seed: 311
# Test ep reward: -28.907901408865538 seed: 893
# Test ep reward: -28.228434478897587 seed: 959
# Test ep reward: -28.25587321234396 seed: 89
# Test ep reward: -30.074113810932257 seed: 404
# Test ep reward: -29.664166547027715 seed: 253
# Test ep reward: -29.74323827868009 seed: 72
# Average test reward: -29.02342119209577 episode length: 14.9

# %%
Video(work_dir/'video'/'TargetReacher-v0'/'test'/f'ex1-episode-0.mp4',
      embed=True, html_attributes="loop autoplay") # Set html_attributes="controls" for video control
# Out:
# <video loop autoplay  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# <a id='T4'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Task 4.</b> Visualizing Behavior (10 points) </h3>
#
# Now, let us visualize the reward function for the second behavior (reaching the goal [1,1]). Plot the values of the second reward function from Task 3 and the learned best action as a function of the state (the joint positions). Use the code below as a starting point. After plotting, answer the questions below.
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import gymnasium as gym
from agent import Agent,Policy

# %%
env_name = "TargetReacher-v0" 
resolution = 101  # Resolution of the policy/reward image

# Load policy from default path to plot
policy_dir = Path().cwd()/'results'/'model'/f'{env_name}_params.pt'

sns.set()

# Create a gym environment
env = gym.make(env_name)

action_space_dim = u.get_space_dim(env.action_space)
observation_space_dim = u.get_space_dim(env.observation_space)
policy = Policy(observation_space_dim, action_space_dim)

if policy_dir:
    policy.load_state_dict(torch.load(policy_dir))
    print("Loading policy from", policy_dir)
else:
    print("Plotting a random policy")
# Out:
# ---------------------------------------------------------------------------
# NameNotFound                              Traceback (most recent call last)
# Cell In[15], line 10
#       7 sns.set()
#       9 # Create a gym environment
# ---> 10 env = gym.make(env_name)
#      12 action_space_dim = u.get_space_dim(env.action_space)
#      13 observation_space_dim = u.get_space_dim(env.observation_space)
#
# File /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:741, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     738     assert isinstance(id, str)
#     740     # The environment name can include an unloaded module in "module:env_name" style
# --> 741     env_spec = _find_spec(id)
#     743 assert isinstance(env_spec, EnvSpec)
#     745 # Update the env spec kwargs with the `make` kwargs
#
# File /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:527, in _find_spec(env_id)
#     521     logger.warn(
#     522         f"Using the latest versioned environment `{new_env_id}` "
#     523         f"instead of the unversioned environment `{env_name}`."
#     524     )
#     526 if env_spec is None:
# --> 527     _check_version_exists(ns, name, version)
#     528     raise error.Error(
#     529         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     530     )
#     532 return env_spec
#
# File /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:393, in _check_version_exists(ns, name, version)
#     390 if get_env_id(ns, name, version) in registry:
#     391     return
# --> 393 _check_name_exists(ns, name)
#     394 if version is None:
#     395     return
#
# File /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:370, in _check_name_exists(ns, name)
#     367 namespace_msg = f" in namespace {ns}" if ns else ""
#     368 suggestion_msg = f" Did you mean: `{suggestion[0]}`?" if suggestion else ""
# --> 370 raise error.NameNotFound(
#     371     f"Environment `{name}` doesn't exist{namespace_msg}.{suggestion_msg}"
#     372 )
#
# NameNotFound: Environment `TargetReacher` doesn't exist. Did you mean: `Reacher`?

# %%
env_name = "TargetReacher-v0" 
resolution = 101  # Resolution of the policy/reward image

# Load policy from default path to plot
policy_dir = Path().cwd()/'results'/'model'/f'{env_name}_params.pt'

sns.set()

# Create a gym environment
env = gym.make(env_name)

action_space_dim = u.get_space_dim(env.action_space)
observation_space_dim = u.get_space_dim(env.observation_space)
policy = Policy(observation_space_dim, action_space_dim)

if policy_dir:
    policy.load_state_dict(torch.load(policy_dir))
    print("Loading policy from", policy_dir)
else:
    print("Plotting a random policy")
# Out:
# ---------------------------------------------------------------------------
# NameNotFound                              Traceback (most recent call last)
# Cell In[16], line 10
#       7 sns.set()
#       9 # Create a gym environment
# ---> 10 env = gym.make(env_name)
#      12 action_space_dim = u.get_space_dim(env.action_space)
#      13 observation_space_dim = u.get_space_dim(env.observation_space)
#
# File /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:741, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     738     assert isinstance(id, str)
#     740     # The environment name can include an unloaded module in "module:env_name" style
# --> 741     env_spec = _find_spec(id)
#     743 assert isinstance(env_spec, EnvSpec)
#     745 # Update the env spec kwargs with the `make` kwargs
#
# File /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:527, in _find_spec(env_id)
#     521     logger.warn(
#     522         f"Using the latest versioned environment `{new_env_id}` "
#     523         f"instead of the unversioned environment `{env_name}`."
#     524     )
#     526 if env_spec is None:
# --> 527     _check_version_exists(ns, name, version)
#     528     raise error.Error(
#     529         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     530     )
#     532 return env_spec
#
# File /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:393, in _check_version_exists(ns, name, version)
#     390 if get_env_id(ns, name, version) in registry:
#     391     return
# --> 393 _check_name_exists(ns, name)
#     394 if version is None:
#     395     return
#
# File /opt/software/lib/python3.10/site-packages/gymnasium/envs/registration.py:370, in _check_name_exists(ns, name)
#     367 namespace_msg = f" in namespace {ns}" if ns else ""
#     368 suggestion_msg = f" Did you mean: `{suggestion[0]}`?" if suggestion else ""
# --> 370 raise error.NameNotFound(
#     371     f"Environment `{name}` doesn't exist{namespace_msg}.{suggestion_msg}"
#     372 )
#
# NameNotFound: Environment `TargetReacher` doesn't exist. Did you mean: `Reacher`?

# %%
# Create a grid and initialize arrays to store rewards and actions
npoints = resolution
state_range = np.linspace(-np.pi, np.pi, npoints)
rewards = np.zeros((npoints, npoints))
actions = np.zeros((npoints, npoints), dtype=np.int32)

# Loop through state[0] and state[1]
for i,th1 in enumerate(state_range):
    for j,th2 in enumerate(state_range):
        # Create the state vector from th1, th2
        state = np.array([th1, th2])

        # Query the policy and find the most probable action
        with torch.no_grad():
            action_dist, _ = policy(torch.from_numpy(state).float().unsqueeze(0))
        action_probs = action_dist.probs.numpy()

        # TODO: Task 4: 1. What's the best action, according to the policy?
        # .             2. Compute the reward given state
        ########## Your code starts here ##########
    
        actions[i,j]=np.argmax(action_probs)
        rewards[i,j]=env.get_reward(state,actions[i,j],state) 
    
        # Use the action probabilities in the action_probs vector
        # (it's a numpy array)
        
        
        ########## Your code ends here ##########
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 15
#      13 # Query the policy and find the most probable action
#      14 with torch.no_grad():
# ---> 15     action_dist, _ = policy(torch.from_numpy(state).float().unsqueeze(0))
#      16 action_probs = action_dist.probs.numpy()
#      18 # TODO: Task 4: 1. What's the best action, according to the policy?
#      19 # .             2. Compute the reward given state
#      20 ########## Your code starts here ##########
#
# NameError: name 'policy' is not defined

# %%
# Create the reward plot
num_ticks = 10
tick_skip = max(1, npoints // num_ticks)
tick_shift = 2*np.pi/npoints/2
tick_points = np.arange(npoints)[::tick_skip] + tick_shift
tick_labels = state_range.round(2)[::tick_skip]

sns.heatmap(rewards)
plt.xticks(tick_points, tick_labels, rotation=45)
plt.yticks(tick_points, tick_labels, rotation=45)
plt.xlabel("J2")
plt.ylabel("J1")
plt.title("Reward")
plt.suptitle("Rewards in %s" % env_name)
plt.show()

# %%
# # Create the policy plot
cmap = sns.color_palette("deep", action_space_dim)
sns.heatmap(actions, cmap=cmap, vmin=0, vmax=action_space_dim-1)
plt.xticks(tick_points, tick_labels, rotation=45)
plt.yticks(tick_points, tick_labels, rotation=45)
colorbar = plt.gca().collections[0].colorbar
ticks = np.array(range(action_space_dim))*((action_space_dim-1)/action_space_dim)+0.5
colorbar.set_ticks(ticks)
if env.spec.id == "Reacher-v1":
    # In Reacher, we can replace 0..4 with more readable labels
    labels = ["J1+", "J1-", "J2+", "J2-", "Stop"]
else:
    labels = list(map(str, range(action_space_dim)))
colorbar.set_ticklabels(labels)
plt.xlabel("J2")
plt.ylabel("J1")
plt.title("Best action")
plt.suptitle("Best action in %s" % env_name)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # # Create the policy plot
# ----> 2 cmap = sns.color_palette("deep", action_space_dim)
#       3 sns.heatmap(actions, cmap=cmap, vmin=0, vmax=action_space_dim-1)
#       4 plt.xticks(tick_points, tick_labels, rotation=45)
#
# NameError: name 'action_space_dim' is not defined

# %% [markdown]
# <a id='3.2.1'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 4.1</b> Achieved Performance (5 points) </h3>
#
# Where are the highest and lowest reward achieved?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# The highest reward  is in the white area.  The lowest reward is near the dark area.

# %% [markdown]
# <a id='Q5'></a>
# <div class=" alert alert-warning">
#     <h3><b>Student Question 4.2</b> Analysis of Behaviour (10 points) </h3>
#
# Did the policy learn to reach the goal from every possible state (manipulator configuration) in an optimal way (i.e. with lowest possible number of steps)? Why/why not?
#
# 🔝	<a href='#TOC'><b>Table of Contents</b></a>
# </div>

# %% [markdown]
# No,it didin't. Some actions value is low and  it can't give any rewards.Some actions value is high means it can move to the goal directly,they're the optimal actions.So the perfomance depends on the initial state,when it has a high value,the manipulator can reach the goal in an optimal way otherwise it will need many steps or just fail in finite timesteps.

# %% [markdown]
# # 4. Submitting <a id='4.'></a>
# Ensure all tasks and questions (in ```ex1.ipynb```) are answered and the relevant plots are recorded in the relevant places. Details about attaching images and figures can be found below. The relevant graphs to be included for this assignment are:
# - Task 1, WandB CartPole ```episodesep_reward``` plot
#
#
# <figure style="text-align: center">
# <img src="imgs/Task1 WandB CartPole.png" width="300px">
# <figcaption> Figure x: Task1,WandB CartPole episodesep_reward plot  </figcaption>
#
# </figure>
# - x2 Task 4 reward plots
# <figure style="text-align: center">
# <img src="imgs/x2_rewards.png" width="300px">
# <figcaption> Figure x: x2_rewards  </figcaption>
#
# </figure>
# - x2 Task 4 reward plots
# <figure style="text-align: center">
# <img src="imgs/x2_bestactions.png" width="300px">
# <figcaption> Figure x: x2_bestactions </figcaption>
#
# </figure>
#
# Ensure the correct model files are saved:
# - results/model/CartPole-v1_params.pt
# - results/model/SpinningReacher-v0_params.pt
# - results/model/TargetReacher-v0_params.pt

# %% [markdown]
# ## 4.1 Feedback <a id='4.1'></a>
# In order to help the staff of the course as well as the forthcoming students, it would be great if you could
# answer feedback questionnaire in ```feedback.ipynb```

# %% [markdown]
# Please use the following section to record references.
# # References <a id='5.'></a>
